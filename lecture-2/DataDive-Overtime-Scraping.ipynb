# %% [markdown]
# # Data Dive 2: Loading and Summarizing Data
# ### Overtime: Scraping the Web for Unique Data
#
# #### [Web scraping](https://en.wikipedia.org/wiki/Web_scraping) is the process of extracting data from html code on the internet.
#
# Resources on web scraping:
# * [Digital Ocean Tutorial](https://www.digitalocean.com/community/tutorials/how-to-scrape-web-pages-with-beautiful-soup-and-python-3) (requests, Beautiful Soup)
# * [DataCamp Tutorial](https://www.datacamp.com/community/tutorials/web-scraping-using-python) (urllib, Beautiful Soup)
# * [Hitchhiker's Guide to Python](https://docs.python-guide.org/scenarios/scrape/) (requests, lxml)
#
# **Important Note**: This is for demonstration purposes only, and only harvests content from individual pages. When building a scraper to harvest large amounts of data from multiple pages, be mindful of [legal](https://www.fastcompany.com/40456140/bots-are-scraping-your-public-data-for-cash-amid-murky-laws-and-ethics-linkedin-hiq) and [ethical](https://towardsdatascience.com/ethics-in-web-scraping-b96b18136f01) issues in web scraping.
#
# ## Today's Exercise
# Say we want to learn more about where Google's offices are located. Helpfully, the provide a list of all of their campuses globally at [google.com/about/locations](https://www.google.com/about/locations). However, copying this list by hand to do data analysis on would be frustrating and time-consuming. Let's take a look at how web scraping can make this process easier.
#
# First, let's import all of the packages we'll need for today's exercise. There are a wide variety of packages that can be helpful, but today we'll be using *requests* and *Beautiful Soup* to pull the contents of these websites.

# %%
import re
import pandas as pd
from bs4 import BeautifulSoup as soup
import requests

# %% [markdown]
# First, we use the *requests* package to get the content of the google site we'd like to extract office location information from:

# %%
url = 'https://www.google.com/about/locations/'
site_source = requests.get(url)

# %% [markdown]
# This is going to give us an enormous amount of content - everything we would get if we looked directly at the source code in the browser.

# %%
print(site_source.text)
# Out:
# <!DOCTYPE html>
#
#
#
#
#
# <html lang="en" dir="ltr" class="google glue-flexbox spa"  locale="en_us" user-region="north-america">
#   <head>
#
#         <meta charset="utf-8">
#
#         <meta name="viewport" content="initial-scale=1, minimum-scale=1, width=device-width">
#
#         <title>Our Locations | Google</title>
#
#         <meta name="description" content="Google has more than 70 offices in 50 countries. View a directory of our locations around the world.">
#
#         <link href="//fonts.googleapis.com/css?family=Roboto:100,300,400,500,700|Google+Sans:400,500,700,900|Google+Sans+Display:400,500" rel="stylesheet">
#
#         <link href="/assets/css/main.min.css?cache=22bf53b" rel="stylesheet">
#
#         <script async="" defer="" src="//www.google.com/insights/consumersurveys/async_survey?site=zohcrlcvmavjct24cpvw6ns7oy"></script>
#
#
#       <meta property="og:description" content="Google has more than 70 offices in 50 countries. View a directory of our locations around the world.">
#       <meta property="og:title" content="Our Locations | Google">
#       <meta property="og:image" content="https://lh3.googleusercontent.com/gi7X34TTW6Uy2F1aiwO9N5GHmkftlVOmfdvWRKUrK3ASh4LV3cKMn-cIJKMj0AiLwVAqLqhouTxohCpQjxkrkk7T1op-503rC4DK6A=w600-l80-sg-rj">
#       <meta property="og:image:width" content="600">
#       <meta property="og:image:height" content="315">
#       <meta property="og:type" content="website">
#       <meta property="og:url" content="//www.google.com/locations/">
#       <meta name="twitter:card" content="summary_large_image">
#       <meta name="twitter:site" content="@google">
#       <meta name="twitter:title" content="Our Locations | Google">
#       <meta name="twitter:description" content="">
#       <meta name="twitter:image" content="https://lh3.googleusercontent.com/gi7X34TTW6Uy2F1aiwO9N5GHmkftlVOmfdvWRKUrK3ASh4LV3cKMn-cIJKMj0AiLwVAqLqhouTxohCpQjxkrkk7T1op-503rC4DK6A=w600-l80-sg-rj">
#       <meta property="google:search-sre-monitor" content="en_us">
#
#       <link rel="apple-touch-icon" href="https://www.gstatic.com/images/branding/googleg/2x/googleg_standard_color_120dp.png">
#       <link rel="apple-touch-icon-precomposed" href="https://www.gstatic.com/images/branding/googleg/2x/googleg_standard_color_120dp.png">
#
#         <link rel="canonical" href="https://about.google/intl/en_us/locations/">
#
#       <script>
# (function(){document.documentElement.classList.remove("google");document.documentElement.classList.add("google-js");}).call(window)      </script>
#
#       <!--[if lte IE 8]>
#         <script src="//www.gstatic.com/external_hosted/html5shiv/html5shiv.js"></script>
#       <![endif]-->
#
#   </head>
#
#   <body data-ng-controller="MainCtrl as mainCtrl">
#
#
# <!-- Google Tag Manager -->
# <noscript><iframe src="//www.googletagmanager.com/ns.html?id=GTM-WQZB4J"
# height="0" width="0" style="display:none;visibility:hidden;"></iframe></noscript>
# <script type="text/javascript">
# var dataLayer = [{'gtm.blacklist':['customScripts','nonGoogleScripts','nonGooglePixels','customPixels']}];
# (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js',
# locale:window.location.pathname.split('/').indexOf('intl') === -1 ? 'root' : window.location.pathname.split('/')[2].replace(/_ALL/, ''),
# locale_fallback:(document.childNodes[1].attributes.locale || {}).value});
# var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-WQZB4J');
# </script>
#
#
# <header class="header" data-about-nav>
#   <div class="header-inner">
#     <h1 class="product-logo">
#       <a href="../"
#           target="_self"
#           aria-label="Google"
#
#       data-g-category="header"
#       data-g-action="navigation"
#       data-g-label="Logo"
#         data-g-module-type="Main Nav"
#         data-g-href="/"
# >
#           <svg alt="Google"  class="logo-svg " xmlns="http://www.w3.org/2000/svg" viewBox="0 0 86 28">
#     <path fill="#4285F4" d="M10.4,21C4.7,21,0,16.2,0,10.5S4.7,0,10.4,0c3.1,0,5.3,1.3,7,2.9l-1.9,2c-1.2-1.2-2.8-2-5-2
#       c-4.1,0-7.3,3.4-7.3,7.6s3.2,7.6,7.3,7.6c2.7,0,4.2-1.1,5.1-2.1c0.8-0.8,1.3-2,1.5-3.8h-6.6V9.3h9.3c0.1,0.5,0.2,1.1,0.2,1.8
#       c0,2.2-0.5,5-2.4,6.9C15.7,20,13.4,21,10.4,21z"/>
#     <path fill="#EA4335" d="M34.2,14.1c0,3.9-2.9,6.7-6.6,6.7s-6.6-2.8-6.6-6.7s2.9-6.7,6.6-6.7S34.2,10.2,34.2,14.1z M31.4,14.1
#       c0-2.5-1.7-4.1-3.7-4.1c-1.9,0-3.7,1.6-3.7,4.1c0,2.4,1.7,4.1,3.7,4.1C29.6,18.2,31.4,16.5,31.4,14.1z"/>
#     <path fill="#FBBC03" d="M48.4,14.1c0,3.9-2.9,6.7-6.6,6.7s-6.6-2.8-6.6-6.7s2.9-6.7,6.6-6.7S48.4,10.2,48.4,14.1z M45.5,14.1
#       c0-2.5-1.7-4.1-3.7-4.1c-1.9,0-3.7,1.6-3.7,4.1c0,2.4,1.7,4.1,3.7,4.1C43.8,18.2,45.5,16.5,45.5,14.1z"/>
#     <path fill="#4285F4" d="M61.7,7.8V20c0,5-2.7,7-6.1,7c-3.2,0-5-2.2-5.8-4l2.5-1.1c0.4,1.1,1.5,2.4,3.3,2.4c2.1,0,3.4-1.4,3.4-3.9v-1
#       h-0.1c-0.6,0.8-1.8,1.6-3.4,1.6c-3.3,0-6.2-2.9-6.2-6.8s2.9-6.7,6.2-6.7c1.6,0,2.7,0.7,3.4,1.6h0.1V7.8H61.7z M59.2,14.1
#       c0-2.4-1.5-4.1-3.5-4.1c-1.9,0-3.5,1.7-3.5,4.1s1.5,4.1,3.5,4.1C57.7,18.2,59.2,16.5,59.2,14.1z"/>
#     <path fill="#34A853" d="M66.4,1.1v19.8h-2.8V1.1H66.4z"/>
#     <path fill="#EA4335" d="M77.7,16.3l2.2,1.6c-0.7,1.1-2.5,3-5.5,3c-3.7,0-6.5-2.9-6.5-6.7c0-4,2.8-6.7,6.2-6.7c3.4,0,5,2.8,5.6,4.3
#       l0.3,0.7l-8.8,3.7c0.7,1.4,1.7,2,3.2,2S76.9,17.5,77.7,16.3z M70.8,14l5.8-2.5c-0.4-0.8-1.3-1.5-2.4-1.5C72.7,10,70.7,11.3,70.8,14
#       z"/>
#   </svg>
#
#       </a>
#     </h1>
#     <button class="nav-toggle-button outside" data-about-nav-toggle aria-label="Navigation menu toggle"
#
#       data-g-category="header"
#       data-g-action="navigation"
#       data-g-label="Navigation menu toggle"
#         data-g-module-type="Main Nav"
# >
#         <svg alt="Open navigation menu"  class="menu-bars" xmlns="http://www.w3.org/2000/svg" width="24px" height="24px" viewBox="0 0 24 24">
#     <path d="M3 18h18v-2H3v2zm0-5h18v-2H3v2zm0-7v2h18V6H3z"></path>
#   </svg>
#   <img alt="Open navigation menu"  class="menu-bars" src="/assets/img/menu.png?cache=38c6aed" height="24" width="24">
#
#         <svg alt="Close navigation menu"  class="menu-close" xmlns="http://www.w3.org/2000/svg" width="24px" height="24px" viewBox="0 0 24 24">
#     <path d="M19 6.41L17.59 5 12 10.59 6.41 5 5 6.41 10.59 12 5 17.59 6.41 19 12 13.41 17.59 19 19 17.59 13.41 12z"></path>
#   </svg>
#   <img alt="Close navigation menu"  class="menu-close" src="/assets/img/close.png?cache=5628868" height="24" width="24">
#
#     </button>
#
#     <nav class="top-nav">
#
#       <h1 class="product-logo">
#         <a href="../"
#             target="_self"
#
#       data-g-category="header"
#       data-g-action="navigation"
#       data-g-label="Logo"
#         data-g-module-type="Main Nav"
#         data-g-href="/"
# >
#             <svg alt="Google"  class="logo-svg " xmlns="http://www.w3.org/2000/svg" viewBox="0 0 86 28">
#     <path fill="#4285F4" d="M10.4,21C4.7,21,0,16.2,0,10.5S4.7,0,10.4,0c3.1,0,5.3,1.3,7,2.9l-1.9,2c-1.2-1.2-2.8-2-5-2
#       c-4.1,0-7.3,3.4-7.3,7.6s3.2,7.6,7.3,7.6c2.7,0,4.2-1.1,5.1-2.1c0.8-0.8,1.3-2,1.5-3.8h-6.6V9.3h9.3c0.1,0.5,0.2,1.1,0.2,1.8
#       c0,2.2-0.5,5-2.4,6.9C15.7,20,13.4,21,10.4,21z"/>
#     <path fill="#EA4335" d="M34.2,14.1c0,3.9-2.9,6.7-6.6,6.7s-6.6-2.8-6.6-6.7s2.9-6.7,6.6-6.7S34.2,10.2,34.2,14.1z M31.4,14.1
#       c0-2.5-1.7-4.1-3.7-4.1c-1.9,0-3.7,1.6-3.7,4.1c0,2.4,1.7,4.1,3.7,4.1C29.6,18.2,31.4,16.5,31.4,14.1z"/>
#     <path fill="#FBBC03" d="M48.4,14.1c0,3.9-2.9,6.7-6.6,6.7s-6.6-2.8-6.6-6.7s2.9-6.7,6.6-6.7S48.4,10.2,48.4,14.1z M45.5,14.1
#       c0-2.5-1.7-4.1-3.7-4.1c-1.9,0-3.7,1.6-3.7,4.1c0,2.4,1.7,4.1,3.7,4.1C43.8,18.2,45.5,16.5,45.5,14.1z"/>
#     <path fill="#4285F4" d="M61.7,7.8V20c0,5-2.7,7-6.1,7c-3.2,0-5-2.2-5.8-4l2.5-1.1c0.4,1.1,1.5,2.4,3.3,2.4c2.1,0,3.4-1.4,3.4-3.9v-1
#       h-0.1c-0.6,0.8-1.8,1.6-3.4,1.6c-3.3,0-6.2-2.9-6.2-6.8s2.9-6.7,6.2-6.7c1.6,0,2.7,0.7,3.4,1.6h0.1V7.8H61.7z M59.2,14.1
#       c0-2.4-1.5-4.1-3.5-4.1c-1.9,0-3.5,1.7-3.5,4.1s1.5,4.1,3.5,4.1C57.7,18.2,59.2,16.5,59.2,14.1z"/>
#     <path fill="#34A853" d="M66.4,1.1v19.8h-2.8V1.1H66.4z"/>
#     <path fill="#EA4335" d="M77.7,16.3l2.2,1.6c-0.7,1.1-2.5,3-5.5,3c-3.7,0-6.5-2.9-6.5-6.7c0-4,2.8-6.7,6.2-6.7c3.4,0,5,2.8,5.6,4.3
#       l0.3,0.7l-8.8,3.7c0.7,1.4,1.7,2,3.2,2S76.9,17.5,77.7,16.3z M70.8,14l5.8-2.5c-0.4-0.8-1.3-1.5-2.4-1.5C72.7,10,70.7,11.3,70.8,14
#       z"/>
#   </svg>
#
#         </a>
#       </h1>
#
#       <ul>
#           <li>
#               <a href="../"
#                   title="About"
#                   target="_self"
#
#       data-g-category="header"
#       data-g-action="navigation"
#       data-g-label="About"
#         data-g-module-type="Main Nav"
#         data-g-href="/"
# >
#                 About
#               </a>
#             </li>
#           <li>
#               <a href="../products/"
#                   title="Our products"
#                   target="_self"
#
#       data-g-category="header"
#       data-g-action="navigation"
#       data-g-label="Our products"
#         data-g-module-type="Main Nav"
#         data-g-href="/products/"
# >
#                 Our products
#               </a>
#             </li>
#           <li>
#               <a href="../commitments/"
#                   title="Our commitments"
#                   target="_self"
#
#       data-g-category="header"
#       data-g-action="navigation"
#       data-g-label="Our commitments"
#         data-g-module-type="Main Nav"
#         data-g-href="/commitments/"
# >
#                 Our commitments
#               </a>
#             </li>
#           <li>
#               <a href="../stories/"
#                   title="Our stories"
#                   target="_self"
#
#       data-g-category="header"
#       data-g-action="navigation"
#       data-g-label="Our stories"
#         data-g-module-type="Main Nav"
#         data-g-href="/stories/"
# >
#                 Our stories
#               </a>
#             </li>
#       </ul>
#
#     </nav>
#
#   </div>
# </header>
#         <main class="static-content-view" data-ui-view="main">
#   <section
#       class="section company offices"
#       data-ng-controller="LocationsCtrl as locationsCtrl"
#       data-page-title="Our Locations"
#       data-page-description="Google has more than 70 offices in 50 countries. View a directory of our locations around the world.">
#
#     <h2 class="section-title">
#       Our offices
#     </h2>
#
#     <div data-ng-cloak="">
#         <div class="map-container"
#       data-ng-controller="OfficesMapCtrl as officesMapCtrl"
#       data-locale-region="north-america"
#       data-locale-office="mountain-view">
#     <div
#         class="map-canvas"
#         id="map-canvas"
#         data-google-maps
#         data-google-maps-markers="officesMapCtrl.officesList"
#         data-google-maps-position="locationsCtrl.mapPosition || officesMapCtrl.mapPosition"
#         data-google-maps-selected="locationsCtrl.selectedOffice">
#     </div>
#
#     <div
#         class="infopane-wrap"
#         data-office-infopane="officesMapCtrl.getOfficeData(locationsCtrl.selectedOffice)"
#         data-ng-if="!!officesMapCtrl.getOfficeData(locationsCtrl.selectedOffice)">
#       <div class="infopane cols-row">
#         <div class="infopane-main">
#           <div class="infopane-office-name">
#             <a data-ng-href="https://maps.google.com/?q={[officesMapCtrl.getOfficeData(locationsCtrl.selectedOffice).name]}@{[officesMapCtrl.getOfficeData(locationsCtrl.selectedOffice).lat]},{[officesMapCtrl.getOfficeData(locationsCtrl.selectedOffice).lng]}&amp;hl=en"
#                 target="_blank"
#                 data-ng-if="!officesMapCtrl.getOfficeData(locationsCtrl.selectedOffice).link">
#               {[officesMapCtrl.getOfficeData(locationsCtrl.selectedOffice).name]}
#             </a>
#
#             <a data-ng-href="{[officesMapCtrl.getOfficeData(locationsCtrl.selectedOffice).link]}"
#                 target="_blank"
#                 data-ng-if="officesMapCtrl.getOfficeData(locationsCtrl.selectedOffice).link">
#               {[officesMapCtrl.getOfficeData(locationsCtrl.selectedOffice).name]}
#             </a>
#           </div>
#           <div class="infopane-office-address" data-ng-bind-html="officesMapCtrl.getOfficeData(locationsCtrl.selectedOffice).address">
#           </div>
#           <div data-ng-if="officesMapCtrl.getOfficeData(locationsCtrl.selectedOffice).phone">
#             Phone:
#             <span data-phone-number="{[officesMapCtrl.getOfficeData(locationsCtrl.selectedOffice).phone]}">
#               {[officesMapCtrl.getOfficeData(locationsCtrl.selectedOffice).phone]}
#             </span>
#           </div>
#           <div data-ng-if="officesMapCtrl.getOfficeData(locationsCtrl.selectedOffice).fax">
#             Phone:
#             {[officesMapCtrl.getOfficeData(locationsCtrl.selectedOffice).fax]}
#           </div>
#         </div>
#         <div class="infopane-sub">
#           <a data-ng-href="https://www.google.com/maps/dir/Current+Location/{[officesMapCtrl.getOfficeData(locationsCtrl.selectedOffice).lat]},{[officesMapCtrl.getOfficeData(locationsCtrl.selectedOffice).lng]}?hl=en"
#               class="directions-link"
#               target="_blank"
#               data-ng-if="!officesMapCtrl.getOfficeData(locationsCtrl.selectedOffice).link">
#             Directions
#           </a>
#
#           <a data-ng-href="{[infopaneCtrl.officeData.link]}"
#               class="directions-link"
#               target="_blank"
#               data-ng-if="officesMapCtrl.getOfficeData(locationsCtrl.selectedOffice).link">
#             Directions
#           </a>
#         </div>
#       </div>
#     </div>
#   </div>
#
#
#         <nav
#       class="office-nav"
#       data-glue-breakpoint-match="['small', 'medium', 'large']">
#     <ul>
#         <li class="nav-item"
#             data-ng-class="{selected: 'north-america' === locationsCtrl.selectedRegion}">
#           <a href="../locations/?region=north-america"
#               data-ng-class="{selected: 'north-america' === locationsCtrl.selectedRegion}"
#               class="nav-anchor"
#
# >
#             North America
#           </a>
#         </li>
#         <li class="nav-item"
#             data-ng-class="{selected: 'latin-america' === locationsCtrl.selectedRegion}">
#           <a href="../locations/?region=latin-america"
#               data-ng-class="{selected: 'latin-america' === locationsCtrl.selectedRegion}"
#               class="nav-anchor"
#
# >
#             Latin America
#           </a>
#         </li>
#         <li class="nav-item"
#             data-ng-class="{selected: 'europe' === locationsCtrl.selectedRegion}">
#           <a href="../locations/?region=europe"
#               data-ng-class="{selected: 'europe' === locationsCtrl.selectedRegion}"
#               class="nav-anchor"
#
# >
#             Europe
#           </a>
#         </li>
#         <li class="nav-item"
#             data-ng-class="{selected: 'asia-pacific' === locationsCtrl.selectedRegion}">
#           <a href="../locations/?region=asia-pacific"
#               data-ng-class="{selected: 'asia-pacific' === locationsCtrl.selectedRegion}"
#               class="nav-anchor"
#
# >
#             Asia Pacific
#           </a>
#         </li>
#         <li class="nav-item"
#             data-ng-class="{selected: 'africa-middle-east' === locationsCtrl.selectedRegion}">
#           <a href="../locations/?region=africa-middle-east"
#               data-ng-class="{selected: 'africa-middle-east' === locationsCtrl.selectedRegion}"
#               class="nav-anchor"
#
# >
#             Africa &amp; Middle East
#           </a>
#         </li>
#     </ul>
#     <div class="line-selected"></div>
#   </nav>
#
#   <div class="offices-list-container"
#       data-glue-breakpoint-match="['small', 'medium', 'large']">
#       <ul class="regions-list-desktop">
#
#           <li class="offices-list"
#               data-ng-show="'africa-middle-east' === locationsCtrl.selectedRegion">
#             <div class="office">
#               <div class="office-photo">
#                 <img src="https://lh3.googleusercontent.com/xw0iylnw3b3-qxwoNzLSLJlAAPtkF1KONnIoBTDHtURr04fzH9DeO08GYvEsKYQtE9GCdOMTk_s08H6-btSquKo3moeILfc3Kpu4MA">
#               </div>
#               <div class="office-info">
#                 <h2 class="office-name" itemprop="name">
#                   Dubai
#                 </h2>
#                 <div class="office-address" itemprop="address">TECOM Zone, Dubai Internet City
# Dubai, United Arab Emirates</div>
#                   <div class="office-phone-number">
#                     Phone:
#                     <span
#                         itemprop="telephone"
#                         class="phone-number"
#                         data-phone-number="+971 4 4509500">
#                       +971 4 4509500
#                     </span>
#                   </div>
#
#
#
#                 <div class="directions">
#                   <a href="https://www.google.com/maps/dir/Current+Location/25.0929,55.1591?hl=en" target="_blank" rel="noopener">
#                     Directions
#                   </a>
#                 </div>
#               </div>
#             </div>
#           </li>
#
#           <li class="offices-list"
#               data-ng-show="'africa-middle-east' === locationsCtrl.selectedRegion">
#             <div class="office">
#               <div class="office-photo">
#                 <img src="https://lh3.googleusercontent.com/syKfT9cVMzLi0d4_DSiJztWGwcmWct6IEbpAApEFk_G8ym0xyLLxMBT484zROIOZHMSe9N1o-QQrCAqVWfKRSY6EOeJY9Qa1ftwb">
#               </div>
#               <div class="office-info">
#                 <h2 class="office-name" itemprop="name">
#                   Haifa
#                 </h2>
#                 <div class="office-address" itemprop="address">Building 30
# MATAM, Advanced Technology Center
# Haifa, 3190500
# Israel </div>
#                   <div class="office-phone-number">
#                     Phone:
#                     <span
#                         itemprop="telephone"
#                         class="phone-number"
#                         data-phone-number="+972-74-746-6245">
#                       +972-74-746-6245
#                     </span>
#                   </div>
#
#
#
#                 <div class="directions">
#                   <a href="https://www.google.com/maps/dir/Current+Location/32.78897,34.958432?hl=en" target="_blank" rel="noopener">
#                     Directions
#                   </a>
#                 </div>
#               </div>
#             </div>
#           </li>
#
#           <li class="offices-list"
#               data-ng-show="'africa-middle-east' === locationsCtrl.selectedRegion">
#             <div class="office">
#               <div class="office-photo">
#                 <img src="https://lh3.googleusercontent.com/_mdN7z1Q-9fKgpHTb1rQJosllxqn7glRJ_G2enX4WPmImuJjLHKw-JBZ8z5B9vMSo12SexGBOD1i2NHXqEy4OaOJekn0g3Fp3bDk_Q">
#               </div>
#               <div class="office-info">
#                 <h2 class="office-name" itemprop="name">
#                   Istanbul
#                 </h2>
#                 <div class="office-address" itemprop="address">Eski Buyukdere Caddesi No: 209
# 34394
# Istanbul, Turkey</div>
#
#
#
#                 <div class="directions">
#                   <a href="https://www.google.com/maps/dir/Current+Location/41.081697,29.00859?hl=en" target="_blank" rel="noopener">
#                     Directions
#                   </a>
#                 </div>
#               </div>
#             </div>
#           </li>
#
#           <li class="offices-list"
#               data-ng-show="'africa-middle-east' === locationsCtrl.selectedRegion">
#             <div class="office">
#               <div class="office-photo">
#                 <img src="https://lh3.googleusercontent.com/EDxefwSgeKyh8zN9VUUGhu3hiBqH7Z3UEOXfZeij7YnUhZLqLElu8dhi4FziOepRun-fjfwIWdf5W8CTG5ZSYMu4k8z9QZjTgjQRuQ">
#               </div>
#               <div class="office-info">
#                 <h2 class="office-name" itemprop="name">
#                   Johannesburg
#                 </h2>
#                 <div class="office-address" itemprop="address">35 Ballyclare Drive Building E
# Johannesburg
# 2191, South Africa</div>
#
#
#
#                 <div class="directions">
#                   <a href="https://www.google.com/maps/dir/Current+Location/-26.0734457,28.032035?hl=en" target="_blank" rel="noopener">
#                     Directions
#                   </a>
#                 </div>
#               </div>
#             </div>
#           </li>
#
#           <li class="offices-list"
#               data-ng-show="'africa-middle-east' === locationsCtrl.selectedRegion">
#             <div class="office">
#               <div class="office-photo">
#                 <img src="https://lh3.googleusercontent.com/BZxU1dJCWFmtVeBqVYFC8SmSzX4CCzO5eedosW1s7sv2b2HoKwEno15vICfeQdsc_BGIaysKb8VyF64IB9hbFzMZ_MlQDJhP7kfF">
#               </div>
#               <div class="office-info">
#                 <h2 class="office-name" itemprop="name">
#                   Tel Aviv
#                 </h2>
#                 <div class="office-address" itemprop="address">Yigal Alon 98
# Tel Aviv, 6789141
# Israel </div>
#                   <div class="office-phone-number">
#                     Phone:
#                     <span
#                         itemprop="telephone"
#                         class="phone-number"
#                         data-phone-number="+972-74-746-6453">
#                       +972-74-746-6453
#                     </span>
#                   </div>
#
#
#
#                 <div class="directions">
#                   <a href="https://www.google.com/maps/dir/Current+Location/32.070043,34.794087?hl=en" target="_blank" rel="noopener">
#                     Directions
#                   </a>
#                 </div>
#               </div>
#             </div>
#           </li>
#       </ul>
#       <ul class="regions-list-desktop">
#
#           <li class="offices-list"
#               data-ng-show="'asia-pacific' === locationsCtrl.selectedRegion">
#             <div class="office">
#               <div class="office-photo">
#                 <img src="https://lh3.googleusercontent.com/YDyQevoY-D0eZQ9sYHp8dQjpFF5JpLfLK-0OM-uJK1oNK3_LRnGJAM0uXi9qb9UigKnVIIXlIgidxhRlnaB_FPtUOqPzrsCSiFZyoQ">
#               </div>
#               <div class="office-info">
#                 <h2 class="office-name" itemprop="name">
#                   Bangalore
#                 </h2>
#                 <div class="office-address" itemprop="address">No. 3, RMZ Infinity - Tower E
# Old Madras Road
# 4th and 5th Floors
# Bangalore, 560 016, India</div>
#                   <div class="office-phone-number">
#                     Phone:
#                     <span
#                         itemprop="telephone"
#                         class="phone-number"
#                         data-phone-number="+91-80-67218000">
#                       +91-80-67218000
#                     </span>
#                   </div>
#
#
#
#                 <div class="directions">
#                   <a href="https://www.google.com/maps/dir/Current+Location/12.99332,77.660176?hl=en" target="_blank" rel="noopener">
#                     Directions
#                   </a>
#                 </div>
#               </div>
#             </div>
#           </li>
#
#           <li class="offices-list"
#               data-ng-show="'asia-pacific' === locationsCtrl.selectedRegion">
#             <div class="office">
#               <div class="office-photo">
#                 <img src="https://lh3.googleusercontent.com/nh9uOUPj6iWjKZSHIrnkfGhIWGBb8thguRM5_ehCOkyF-qfwzYciDJFVRSvQ6QxlSA6eZUMkzgdW9zR0Gab2ZZPg8NlB7V_V3wB5">
#               </div>
#               <div class="office-info">
#                 <h2 class="office-name" itemprop="name">
#                   Bangkok
#                 </h2>
#                 <div class="office-address" itemprop="address">57 Park Ventures Ecoplex
# 14th Floor, Wireless Road
# Bangkok, 10330, Thailand</div>
#
#
#
#                 <div class="directions">
#                   <a href="https://www.google.com/maps/dir/Current+Location/13.742866,100.547983?hl=en" target="_blank" rel="noopener">
#                     Directions
#                   </a>
#                 </div>
#               </div>
#             </div>
#           </li>
#
#           <li class="offices-list"
#               data-ng-show="'asia-pacific' === locationsCtrl.selectedRegion">
#             <div class="office">
#               <div class="office-photo">
#                 <img src="https://lh3.googleusercontent.com/v_tD3VvC8-dnhqSF9xhj5Hx7F_bb3-wieM19i-Ho2C3by6mt7-JpPc7KsYVHUZFqQl5ON3adVEV1N4OlzSvHLrr3sr4GtXErDbGC">
#               </div>
#               <div class="office-info">
#                 <h2 class="office-name" itemprop="name">
#                   Beijing
#                 </h2>
#                 <div class="office-address" itemprop="address">6th Floor, Tower B, Raycom InfoTech Park
# No. 2 Kexueyuan South Road
# Zhongguancun Beijing 100190</div>
#                   <div class="office-phone-number">
#                     Phone:
#                     <span
#                         itemprop="telephone"
#                         class="phone-number"
#                         data-phone-number="+86-10-62503000">
#                       +86-10-62503000
#                     </span>
#                   </div>
#
#
#
#                 <div class="directions">
#                   <a href="https://www.google.com/maps/dir/Current+Location/39.9848878,116.3265708?hl=en" target="_blank" rel="noopener">
#                     Directions
#                   </a>
#                 </div>
#               </div>
#             </div>
#           </li>
#
#           <li class="offices-list"
#               data-ng-show="'asia-pacific' === locationsCtrl.selectedRegion">
#             <div class="office">
#               <div class="office-photo">
#                 <img src="https://lh3.googleusercontent.com/BjYQfVMor1QT5hAkc7DcN6_MJdwaySHY6VJ6IY7mQGJRdXjFZhiP-t4MV_QUbp0tBeuYvuMw3nUetTiI-vFl6-BcialJhhurhFrDVeY">
#               </div>
#               <div class="office-info">
#                 <h2 class="office-name" itemprop="name">
#                   Guangzhou
#                 </h2>
#                 <div class="office-address" itemprop="address">Taikoo Hui Tower 1, No.383 Tianhe Road
# Guangzhou, 510620
# China</div>
#
#
#
#                 <div class="directions">
#                   <a href="https://www.google.com/maps/dir/Current+Location/23.1339728,113.3332488?hl=en" target="_blank" rel="noopener">
#                     Directions
#                   </a>
#                 </div>
#               </div>
#             </div>
#           </li>
#
#           <li class="offices-list"
#               data-ng-show="'asia-pacific' === locationsCtrl.selectedRegion">
#             <div class="office">
#               <div class="office-photo">
#                 <img src="https://lh3.googleusercontent.com/8plKBiWKmwllCXePad0JJ22u1GG7Qe1hveXlx_xJ87XoiQpclQubwxyGxcDU6tkatpb3oi9MYXjm2XszFi5kGn1flfTtjv6MycBWrQ">
#               </div>
#               <div class="office-info">
#                 <h2 class="office-name" itemprop="name">
#                   Gurgaon
#                 </h2>
#                 <div class="office-address" itemprop="address">Sector 15, Part II Village Silokhera
# Gurgaon 122001
# India</div>
#                   <div class="office-phone-number">
#                     Phone:
#                     <span
#                         itemprop="telephone"
#                         class="phone-number"
#                         data-phone-number="+91-12-44512900">
#                       +91-12-44512900
#                     </span>
#                   </div>
#
#
#
#                 <div class="directions">
#                   <a href="https://www.google.com/maps/dir/Current+Location/28.460581,77.048194?hl=en" target="_blank" rel="noopener">
#                     Directions
#                   </a>
#                 </div>
#               </div>
#             </div>
#           </li>
#
#           <li class="offices-list"
#               data-ng-show="'asia-pacific' === locationsCtrl.selectedRegion">
#             <div class="office">
#               <div class="office-photo">
#                 <img src="https://lh3.googleusercontent.com/-Ult8_R6TfQAk16CfjSfl6PLypQBYohUjNjE6xeeektZsrP8XwTv7PnVVE-5Ueh3I-2hPnAdRGg6XrMn9IwI7W1h5LJKtlMVe93Wfw">
#               </div>
#               <div class="office-info">
#                 <h2 class="office-name" itemprop="name">
#                   Hong Kong
#                 </h2>
#                 <div class="office-address" itemprop="address">1 Matheson Street
# Causeway Bay, Hong Kong</div>
#                   <div class="office-phone-number">
#                     Phone:
#                     <span
#                         itemprop="telephone"
#                         class="phone-number"
#                         data-phone-number="+852-3923-5400">
#                       +852-3923-5400
#                     </span>
#                   </div>
#
#
#
#                 <div class="directions">
#                   <a href="https://www.google.com/maps/dir/Current+Location/22.278203,114.18176?hl=en" target="_blank" rel="noopener">
#                     Directions
#                   </a>
#                 </div>
#               </div>
#             </div>
#           </li>
#
#           <li class="offices-list"
#               data-ng-show="'asia-pacific' === locationsCtrl.selectedRegion">
#             <div class="office">
#               <div class="office-photo">
#                 <img src="https://lh3.googleusercontent.com/LAEnc0tzA-JSb5XM5oct5paX98QK9zh_aqa_qKcjAoXo2MChgOjdj_EZpgIZsVAvEY-I0bmMmhCBb5gkoVN4ebqCG9ZfjCbo_stJaw">
#               </div>
#               <div class="office-info">
#                 <h2 class="office-name" itemprop="name">
#                   Hyderabad
#                 </h2>
#                 <div class="office-address" itemprop="address">Survey No. 13, DivyaSree Omega
# Kondapur Village
# Hyderabad, Telangana 500084
# India</div>
#                   <div class="office-phone-number">
#                     Phone:
#                     <span
#                         itemprop="telephone"
#                         class="phone-number"
#                         data-phone-number="+91-40-6619-3000">
#                       +91-40-6619-3000
#                     </span>
#                   </div>
#
#
#
#                 <div class="directions">
#                   <a href="https://www.google.com/maps/dir/Current+Location/17.458461,78.372452?hl=en" target="_blank" rel="noopener">
#                     Directions
#                   </a>
#                 </div>
#               </div>
#             </div>
#           </li>
#
#           <li class="offices-list"
#               data-ng-show="'asia-pacific' === locationsCtrl.selectedRegion">
#             <div class="office">
#               <div class="office-photo">
#                 <img src="https://lh3.googleusercontent.com/JEaMUfOUq6bxN7jeIN1z2me5-JvlLRkrFJgf_A0GvqtOquU6Tfjg0ecKeR_Ck27L0S1zC2t_4I6nVP6pBdBtSKst7tkJEoC7LyYq">
#               </div>
#               <div class="office-info">
#                 <h2 class="office-name" itemprop="name">
#                   Jakarta
#                 </h2>
#                 <div class="office-address" itemprop="address">Pacific Century Place Tower Level 45 SCBD Lot 10,
# Jl. Jend. Sudirman No.53,
# RT.5/RW.3, Senayan, Kby. Baru,
# Kota Jakarta Selatan,
# Daerah Khusus Ibukota Jakarta 12190,
# Indonesia</div>
#
#
#
#                 <div class="directions">
#                   <a href="https://www.google.com/maps/dir/Current+Location/-6.227664,106.808471?hl=en" target="_blank" rel="noopener">
#                     Directions
#                   </a>
#                 </div>
#               </div>
#             </div>
#           </li>
#
#           <li class="offices-list"
#               data-ng-show="'asia-pacific' === locationsCtrl.selectedRegion">
#             <div class="office">
#               <div class="office-photo">
#                 <img src="https://lh3.googleusercontent.com/c5kAdRoyejY1Z5i9A3hYKfIG55GrKdAc0iJjH-gYo-tWd3JUksvsfZx7LU5yzay4HJmxCQEir2cejbZ2LurYfKL_emC9e9PCDVxd">
#               </div>
#               <div class="office-info">
#                 <h2 class="office-name" itemprop="name">
#                   Kuala Lumpur
#                 </h2>
#                 <div class="office-address" itemprop="address">Axiata Tower
# No. 9, Jalan Stesen Sentral 5
# 50470 Kuala Lumpur
# Malaysia</div>
#
#
#
#                 <div class="directions">
#                   <a href="https://www.google.com/maps/dir/Current+Location/3.133445,101.684609?hl=en" target="_blank" rel="noopener">
#                     Directions
#                   </a>
#                 </div>
#               </div>
#             </div>
#           </li>
#
#           <li class="offices-list"
#               data-ng-show="'asia-pacific' === locationsCtrl.selectedRegion">
#             <div class="office">
#               <div class="office-photo">
#                 <img src="https://lh3.googleusercontent.com/U_5KiB8x7T-Rrdp90ygnO1kbZxiWJz4G6CbD6_51CjH5zaMP23upWELryFOe99k_AqlPZschCY7Nx--wYufcIV54HnjGcP3lf28X1A">
#               </div>
#               <div class="office-info">
#                 <h2 class="office-name" itemprop="name">
#                   Melbourne
#                 </h2>
#                 <div class="office-address" itemprop="address">161 Collins Street,
# Melbourne VIC 3000,
# Australia</div>
#
#
#
#                 <div class="directions">
#                   <a href="https://www.google.com/maps/dir/Current+Location/-37.815328,144.968737?hl=en" target="_blank" rel="noopener">
#                     Directions
#                   </a>
#                 </div>
#               </div>
#             </div>
#           </li>
#
#           <li class="offices-list"
#               data-ng-show="'asia-pacific' === locationsCtrl.selectedRegion">
#             <div class="office">
#               <div class="office-photo">
#                 <img src="https://lh3.googleusercontent.com/twldrlVORn84fYsOLwNLabfRPQYX-dJAzJtpam-Ea4D7QIY1pvMa9FCMbpjUFA8uniBg6XAh8pMijf9qnjmEm4d17UFkwRGToiv5Ug">
#               </div>
#               <div class="office-info">
#                 <h2 class="office-name" itemprop="name">
#                   Mumbai
#                 </h2>
#                 <div class="office-address" itemprop="address">3 North Avenue
# Maker Maxity, Bandra Kurla Complex
# Bandra East
# Mumbai, Maharashtra 400051
# India</div>
#                   <div class="office-phone-number">
#                     Phone:
#                     <span
#                         itemprop="telephone"
#                         class="phone-number"
#                         data-phone-number="+91-22-6611-7150">
#                       +91-22-6611-7150
#                     </span>
#                   </div>
#
#
#
#                 <div class="directions">
#                   <a href="https://www.google.com/maps/dir/Current+Location/19.054364,72.850591?hl=en" target="_blank" rel="noopener">
#                     Directions
#                   </a>
#                 </div>
#               </div>
#             </div>
#           </li>
#
#           <li class="offices-list"
#               data-ng-show="'asia-pacific' === locationsCtrl.selectedRegion">
#             <div class="office">
#               <div class="office-photo">
#                 <img src="https://lh3.googleusercontent.com/i8rfvJIUNpLBkmWWSoetUzFGHUd_RaulLh8F3EHme3FMTUtDs8EVWsrFLuaemh1Zd60p5ndCcKq8-ZQN8eibbua-YNzlzQ8AKtHFzrQ">
#               </div>
#               <div class="office-info">
#                 <h2 class="office-name" itemprop="name">
#                   Seoul
#                 </h2>
#                 <div class="office-address" itemprop="address">Google Korea LLC.
# 22nd Floor, Gangnam Finance Center
# 152 Teheran-ro, Gangnam-gu
# Seoul 06236
# South Korea</div>
#                   <div class="office-phone-number">
#                     Phone:
#                     <span
#                         itemprop="telephone"
#                         class="phone-number"
#                         data-phone-number="+82-2-531-9000">
#                       +82-2-531-9000
#                     </span>
#                   </div>
#
#
#
#                 <div class="directions">
#                   <a href="https://www.google.com/maps/dir/Current+Location/37.500295,127.036843?hl=en" target="_blank" rel="noopener">
#                     Directions
#                   </a>
#                 </div>
#               </div>
#             </div>
#           </li>
#
#           <li class="offices-list"
#               data-ng-show="'asia-pacific' === locationsCtrl.selectedRegion">
#             <div class="office">
#               <div class="office-photo">
#                 <img src="https://lh3.googleusercontent.com/wFCKLAJvrAoE_GiXqRNa0w4Rsr0iY_SyMGbO2jnIhLXGanYs1c5_BPE8TxQJw-e14uaLDHjY772V-Vv-Kf3GmrIRSlHjoV9yD339wRQ">
#               </div>
#               <div class="office-info">
#                 <h2 class="office-name" itemprop="name">
#                   Shanghai
#                 </h2>
#                 <div class="office-address" itemprop="address">100 Century Avenue, Pudong
# Shanghai 200120
# China</div>
#                   <div class="office-phone-number">
#                     Phone:
#                     <span
#                         itemprop="telephone"
#                         class="phone-number"
#                         data-phone-number="+86-21-6133-7666">
#                       +86-21-6133-7666
#                     </span>
#                   </div>
#
#
#
#                 <div class="directions">
#                   <a href="https://www.google.com/maps/dir/Current+Location/31.23464,121.507662?hl=en" target="_blank" rel="noopener">
#                     Directions
#                   </a>
#                 </div>
#               </div>
#             </div>
#           </li>
#
#           <li class="offices-list"
#               data-ng-show="'asia-pacific' === locationsCtrl.selectedRegion">
#             <div class="office">
#               <div class="office-photo">
#                 <img src="https://lh3.googleusercontent.com/--5H57B8aG4-DX9s79Spo3ygrsI9NMFnZo1uTZzs5s5AeeOvmiy81k__tu9r7JbRTTLzryK-oUy0UREclmD_qfV81VvaT4K9jJa8gg">
#               </div>
#               <div class="office-info">
#                 <h2 class="office-name" itemprop="name">
#                   Singapore
#                 </h2>
#                 <div class="office-address" itemprop="address">70 Pasir Panjang Road, #03-71,
# Mapletree Business City
# Singapore 117371</div>
#                   <div class="office-phone-number">
#                     Phone:
#                     <span
#                         itemprop="telephone"
#                         class="phone-number"
#                         data-phone-number="+65 6521-8000">
#                       +65 6521-8000
#                     </span>
#                   </div>
#
#
#
#                 <div class="directions">
#                   <a href="https://www.google.com/maps/dir/Current+Location/1.276466,103.798965?hl=en" target="_blank" rel="noopener">
#                     Directions
#                   </a>
#                 </div>
#               </div>
#             </div>
#           </li>
#
#           <li class="offices-list"
#               data-ng-show="'asia-pacific' === locationsCtrl.selectedRegion">
#             <div class="office">
#               <div class="office-photo">
#                 <img src="https://lh3.googleusercontent.com/03Hp4ZwQHs_rWLEWQtrOc62hEHzffD_uoZFCbo56eoeLyZ3L89-Fy5Dd8WcmrGFGK31QC_hZqzuU7f9QhxqjckE7BSLo_arwWjCH1w">
#               </div>
#               <div class="office-info">
#                 <h2 class="office-name" itemprop="name">
#                   Sydney
#                 </h2>
#                 <div class="office-address" itemprop="address">48 Pirrama Road
# Sydney, NSW 2009
# Australia </div>
#                   <div class="office-phone-number">
#                     Phone:
#                     <span
#                         itemprop="telephone"
#                         class="phone-number"
#                         data-phone-number="+61 2 9374 4000">
#                       +61 2 9374 4000
#                     </span>
#                   </div>
#
#
#
#                 <div class="directions">
#                   <a href="https://www.google.com/maps/dir/Current+Location/-33.866638,151.195672?hl=en" target="_blank" rel="noopener">
#                     Directions
#                   </a>
#                 </div>
#               </div>
#             </div>
#           </li>
#
#           <li class="offices-list"
#               data-ng-show="'asia-pacific' === locationsCtrl.selectedRegion">
#             <div class="office">
#               <div class="office-photo">
#                 <img src="https://lh3.googleusercontent.com/h19TQz36F4jY_ZfQxuP5F-THZbl4nAIGz473uFfLqzD_6kpw-r3b6M_Wbna5QvvymqZ-wdnhkLCRt63Pypnc9GyawNqMlQwM1_BYbg">
#               </div>
#               <div class="office-info">
#                 <h2 class="office-name" itemprop="name">
#                   Taipei
#                 </h2>
#                 <div class="office-address" itemprop="address">No. 7 XinYi Road Section 5, Taipei
# Taiwan</div>
#                   <div class="office-phone-number">
#                     Phone:
#                     <span
#                         itemprop="telephone"
#                         class="phone-number"
#                         data-phone-number="+886 2 8729 6000">
#                       +886 2 8729 6000
#                     </span>
#                   </div>
#
#
#
#                 <div class="directions">
#                   <a href="https://www.google.com/maps/dir/Current+Location/25.033447,121.564901?hl=en" target="_blank" rel="noopener">
#                     Directions
#                   </a>
#                 </div>
#               </div>
#             </div>
#           </li>
#
#           <li class="offices-list"
#               data-ng-show="'asia-pacific' === locationsCtrl.selectedRegion">
#             <div class="office">
#               <div class="office-photo">
#                 <img src="https://lh3.googleusercontent.com/i7PqriAmbeqB7KQ4h_8K0T60DD-oAoz7bvvjlB4vx2267l9QHfKBHb7WUMSutYd88Xu4TRwWqIquL05bYcpTyU_58gWp8Ja2Xo2zOfM">
#               </div>
#               <div class="office-info">
#                 <h2 class="office-name" itemprop="name">
#                   Tokyo
#                 </h2>
#                 <div class="office-address" itemprop="address">Roppongi Hills Mori Tower
# 6-10-1 Roppongi
# Minato-ku, Tokyo 106-6126
# Japan</div>
#                   <div class="office-phone-number">
#                     Phone:
#                     <span
#                         itemprop="telephone"
#                         class="phone-number"
#                         data-phone-number="+81-3-6384-9000">
#                       +81-3-6384-9000
#                     </span>
#                   </div>
#
#
#
#                 <div class="directions">
#                   <a href="https://www.google.com/maps/dir/Current+Location/35.66047,139.729231?hl=en" target="_blank" rel="noopener">
#                     Directions
#                   </a>
#                 </div>
#               </div>
#             </div>
#           </li>
#       </ul>
#       <ul class="regions-list-desktop">
#
#           <li class="offices-list"
#               data-ng-show="'europe' === locationsCtrl.selectedRegion">
#             <div class="office">
#               <div class="office-photo">
#                 <img src="https://lh3.googleusercontent.com/tpBMFN5os8K-qXIHiAX5SZEmN5fCzIGrj9FdJtbZPUkC91ookSoY520NYn7fK5yqmh1L1m3F2SJA58v6Qps3JusdrxoFSwk6Ajv2K88">
#               </div>
#               <div class="office-info">
#                 <h2 class="office-name" itemprop="name">
#                   Aarhus
#                 </h2>
#                 <div class="office-address" itemprop="address">Aabogade 15
# 8200 Aarhus
# Denmark</div>
#
#
#
#                 <div class="directions">
#                   <a href="https://www.google.com/maps/dir/Current+Location/56.172249,10.187372?hl=en" target="_blank" rel="noopener">
#                     Directions
#                   </a>
#                 </div>
#               </div>
#             </div>
#           </li>
#
#           <li class="offices-list"
#               data-ng-show="'europe' === locationsCtrl.selectedRegion">
#             <div class="office">
#               <div class="office-photo">
#                 <img src="https://lh3.googleusercontent.com/gG1zKXcSmRyYWHwUn2Z0MITpdqwb52RAEp3uthG2J5Xl-4_Wz7_WmoM6T_TBg6Ut3L1eF-8XENO10sxVIFdQHilj8iRG29wROpSoug">
#               </div>
#               <div class="office-info">
#                 <h2 class="office-name" itemprop="name">
#                   Amsterdam
#                 </h2>
#                 <div class="office-address" itemprop="address">Claude Debussylaan 34
# 1082 MD, Amsterdam
# Netherlands</div>
#
#
#
#                 <div class="directions">
#                   <a href="https://www.google.com/maps/dir/Current+Location/52.337801,4.872066?hl=en" target="_blank" rel="noopener">
#                     Directions
#                   </a>
#                 </div>
#               </div>
#             </div>
#           </li>
#
#           <li class="offices-list"
#               data-ng-show="'europe' === locationsCtrl.selectedRegion">
#             <div class="office">
#               <div class="office-photo">
#                 <img src="https://lh3.googleusercontent.com/XroZnqewSrO6KuvXM5hDHtjUJzUcRQLZYfCKs4jP44dKezRvNx58uxaqUKS4fQ2eXzG2TpJNJ1X2xtfBe7Prl5hSG_xjPEF1xLtFodM">
#               </div>
#               <div class="office-info">
#                 <h2 class="office-name" itemprop="name">
#                   Athens
#                 </h2>
#                 <div class="office-address" itemprop="address">Fragkokklisias 7
# Athens 151 25
# Greece</div>
#
#
#
#                 <div class="directions">
#                   <a href="https://www.google.com/maps/dir/Current+Location/38.03902,23.804595?hl=en" target="_blank" rel="noopener">
#                     Directions
#                   </a>
#                 </div>
#               </div>
#             </div>
#           </li>
#
#           <li class="offices-list"
#               data-ng-show="'europe' === locationsCtrl.selectedRegion">
#             <div class="office">
#               <div class="office-photo">
#                 <img src="https://lh3.googleusercontent.com/XcPyEMiSlLdZJq7nh3orGy3UqjtUHdhxXiwn52ZY47wfEChfZNDO78zDy9H0tBeegogZBZpIE0Q9mdVBGN4aQ0M5vfgz8ZWMEe43Mg">
#               </div>
#               <div class="office-info">
#                 <h2 class="office-name" itemprop="name">
#                   Berlin
#                 </h2>
#                 <div class="office-address" itemprop="address">TucholskystraÃe 2
# 10117 Berlin
# Germany</div>
#                   <div class="office-phone-number">
#                     Phone:
#                     <span
#                         itemprop="telephone"
#                         class="phone-number"
#                         data-phone-number="+49 30 303986300">
#                       +49 30 303986300
#                     </span>
#                   </div>
#
#
#
#                 <div class="directions">
#                   <a href="https://www.google.com/maps/dir/Current+Location/52.5231079,13.39203120000002?hl=en" target="_blank" rel="noopener">
#                     Directions
#                   </a>
#                 </div>
#               </div>
#             </div>
#           </li>
#
#           <li class="offices-list"
#               data-ng-show="'europe' === locationsCtrl.selectedRegion">
#             <div class="office">
#               <div class="office-photo">
#                 <img src="https://lh3.googleusercontent.com/Vdcj2ozYBIOyJLAhRyQic7xjw-OfQ_F5b8M9Kaom_56M2zp8UW65Lm1bYJLLEc4_U4tXfAp-CA81U2O2tdHcXPdsCEUO0hyK_SFKF-Y">
#               </div>
#               <div class="office-info">
#                 <h2 class="office-name" itemprop="name">
#                   Brussels
#                 </h2>
#                 <div class="office-address" itemprop="address">Chaussee d&#39;Etterbeek 180
# 1040 Brussels
# Belgium</div>
#
#
#
#                 <div class="directions">
#                   <a href="https://www.google.com/maps/dir/Current+Location/50.839315,4.380984?hl=en" target="_blank" rel="noopener">
#                     Directions
#                   </a>
#                 </div>
#               </div>
#             </div>
#           </li>
#
#           <li class="offices-list"
#               data-ng-show="'europe' === locationsCtrl.selectedRegion">
#             <div class="office">
#               <div class="office-photo">
#                 <img src="https://lh3.googleusercontent.com/SNSbrYGI_ZBuCl_S8aRh63IIta895tqIUUX3ZT0FWmK7ykhJRy_HNtzoud7XrohnjnSAkuXg9YykkFZqbvkRiZQC7osXrZzGerWdmG8">
#               </div>
#               <div class="office-info">
#                 <h2 class="office-name" itemprop="name">
#                   Copenhagen
#                 </h2>
# ...
#                     target="_blank"
#                     aria-label="LinkedIn"
#
#       data-g-category="footer"
#       data-g-action="follow us"
#       data-g-label="LinkedIn"
#         data-g-href="https://www.linkedin.com/company/google"
# >
#                         <svg alt="LinkedIn"  class="" width="24px" height="24px" viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg" fill="#000">
#     <path d="M20.447 20.452h-3.554v-5.569c0-1.328-.027-3.037-1.852-3.037-1.853 0-2.136 1.445-2.136 2.939v5.667H9.351V9h3.414v1.561h.046c.477-.9 1.637-1.85 3.37-1.85 3.601 0 4.267 2.37 4.267 5.455v6.286zM5.337 7.433c-1.144 0-2.063-.926-2.063-2.065 0-1.138.92-2.063 2.063-2.063 1.14 0 2.064.925 2.064 2.063 0 1.139-.925 2.065-2.064 2.065zm1.782 13.019H3.555V9h3.564v11.452zM22.225 0H1.771C.792 0 0 .774 0 1.729v20.542C0 23.227.792 24 1.771 24h20.451C23.2 24 24 23.227 24 22.271V1.729C24 .774 23.2 0 22.222 0h.003z"/>
#   </svg>
#
#
#                 </a>
#               </li>
#           </ul>
#         </div>
#       </section>
#       <section class="sitemap">
#         <ul class="cols-row footer-links glue-zippy-set-single"
#             id="footer-sitemap-links">
#             <li id="footer-sitemap-about" class="glue-zippy glue-a-zippy--v-smooth-expand">
#               <h4 class="glue-zippy-btn">More about us
#                   <svg alt=""  class="icon" xmlns="http://www.w3.org/2000/svg" width="24px" height="24px" viewBox="0 0 24 24">
#     <path d="M16.59 8.59L12 13.17 7.41 8.59 6 10l6 6 6-6z" fill="currentcolor"/>
#   </svg>
#
#               </h4>
#               <div class="glue-zippy-content">
#                 <ul class="links-list">
#
#
#
# <li>
#   <a href="https://www.google.com/contact/"
# target="_blank"
#       data-g-category="footer"
#       data-g-action="more about us"
#       data-g-label="Contact us"
#         data-g-href="https://www.google.com/contact/"
# >
# Contact us
#   </a>
# </li>
#
#
# <li>
#   <a href="https://abc.xyz/investor/"
# target="_blank"
#       data-g-category="footer"
#       data-g-action="more about us"
#       data-g-label="Investor relations"
#         data-g-href="https://abc.xyz/investor/"
# >
# Investor relations
#   </a>
# </li>
#
#
# <li>
#   <a href="https://careers.google.com/"
# target="_blank"
#       data-g-category="footer"
#       data-g-action="more about us"
#       data-g-label="Careers"
#         data-g-href="https://careers.google.com/"
# >
# Careers
#   </a>
# </li>
#
#
# <li>
#   <a href="../locations/"
# target="_blank"
#       data-g-category="footer"
#       data-g-action="more about us"
#       data-g-label="Locations"
#         data-g-href="/locations/"
# >
# Locations
#   </a>
# </li>
#
#
# <li>
#   <a href="https://www.blog.google/"
# target="_blank"
#       data-g-category="footer"
#       data-g-action="more about us"
#       data-g-label="Blog"
#         data-g-href="https://www.blog.google/"
# >
# Blog
#   </a>
# </li>
#
#
# <li>
#   <a href="https://www.thinkwithgoogle.com/"
# target="_blank"
#       data-g-category="footer"
#       data-g-action="more about us"
#       data-g-label="Think with Google"
#         data-g-href="https://www.thinkwithgoogle.com/"
# >
# Think with Google
#   </a>
# </li>                </ul>
#               </div>
#             </li>
#             <li id="footer-sitemap-related" class="glue-zippy glue-a-zippy--v-smooth-expand">
#               <h4 class="glue-zippy-btn">Press room
#                   <svg alt=""  class="icon" xmlns="http://www.w3.org/2000/svg" width="24px" height="24px" viewBox="0 0 24 24">
#     <path d="M16.59 8.59L12 13.17 7.41 8.59 6 10l6 6 6-6z" fill="currentcolor"/>
#   </svg>
#
#               </h4>
#               <div class="glue-zippy-content">
#                 <ul class="links-list">
#
#
#
# <li>
#   <a href="https://www.blog.google/press/"
# target="_blank"
#       data-g-category="footer"
#       data-g-action="related information"
#       data-g-label="Press inquiries"
#         data-g-href="https://www.blog.google/press/"
# >
# Press inquiries
#   </a>
# </li>
#
#
# <li>
#   <a href="https://www.blog.google/press/"
# target="_blank"
#       data-g-category="footer"
#       data-g-action="related information"
#       data-g-label="Images &amp; B-roll"
#         data-g-href="https://www.blog.google/press/"
# >
# Images &amp; B-roll
#   </a>
# </li>
#
#
# <li>
#   <a href="https://www.google.com/permissions/"
# target="_blank"
#       data-g-category="footer"
#       data-g-action="related information"
#       data-g-label="Permissions"
#         data-g-href="https://www.google.com/permissions/"
# >
# Permissions
#   </a>
# </li>
#
#
# <li>
#   <a href="https://services.google.com/fb/forms/speakerrequest/"
# target="_blank"
#       data-g-category="footer"
#       data-g-action="related information"
#       data-g-label="Speaker requests"
#         data-g-href="https://services.google.com/fb/forms/speakerrequest/"
# >
# Speaker requests
#   </a>
# </li>                </ul>
#               </div>
#             </li>
#             <li id="footer-sitemap-policy-content" class="glue-zippy glue-a-zippy--v-smooth-expand">
#               <h4 class="glue-zippy-btn">Policy
#                   <svg alt=""  class="icon" xmlns="http://www.w3.org/2000/svg" width="24px" height="24px" viewBox="0 0 24 24">
#     <path d="M16.59 8.59L12 13.17 7.41 8.59 6 10l6 6 6-6z" fill="currentcolor"/>
#   </svg>
#
#               </h4>
#               <div class="glue-zippy-content">
#                 <ul class="links-list">
#
#
#
# <li>
#   <a href="https://www.google.com/about/appsecurity/"
# target="_blank"
#       data-g-category="footer"
#       data-g-action="policy"
#       data-g-label="Application security"
#         data-g-href="https://www.google.com/about/appsecurity/"
# >
# Application security
#   </a>
# </li>
#
#
# <li>
#   <a href="https://www.google.com/about/software-principles.html"
# target="_blank"
#       data-g-category="footer"
#       data-g-action="policy"
#       data-g-label="Software principles"
#         data-g-href="https://www.google.com/about/software-principles.html"
# >
# Software principles
#   </a>
# </li>
#
#
# <li>
#   <a href="https://www.google.com/about/unwanted-software-policy.html"
# target="_blank"
#       data-g-category="footer"
#       data-g-action="policy"
#       data-g-label="Unwanted software policy"
#         data-g-href="https://www.google.com/about/unwanted-software-policy.html"
# >
# Unwanted software policy
#   </a>
# </li>
#
#
# <li>
#   <a href="https://www.google.com/about/responsible-supply-chain/"
# target="_blank"
#       data-g-category="footer"
#       data-g-action="policy"
#       data-g-label="Responsible supply chain"
#         data-g-href="https://www.google.com/about/responsible-supply-chain/"
# >
# Responsible supply chain
#   </a>
# </li>
#
#
# <li>
#   <a href="../extended-workforce/"
# target="_blank"
#       data-g-category="footer"
#       data-g-action="policy"
#       data-g-label="Extended workforce"
#         data-g-href="/extended-workforce/"
# >
# Extended workforce
#   </a>
# </li>
#
#
# <li>
#   <a href="../community-guidelines"
# target="_blank"
#       data-g-category="footer"
#       data-g-action="policy"
#       data-g-label="Community guidelines"
#         data-g-href="/community-guidelines"
# >
# Community guidelines
#   </a>
# </li>                </ul>
#               </div>
#             </li>
#             <li id="social-responsibility" class="glue-zippy glue-a-zippy--v-smooth-expand">
#               <h4 class="glue-zippy-btn">Responsibility
#                   <svg alt=""  class="icon" xmlns="http://www.w3.org/2000/svg" width="24px" height="24px" viewBox="0 0 24 24">
#     <path d="M16.59 8.59L12 13.17 7.41 8.59 6 10l6 6 6-6z" fill="currentcolor"/>
#   </svg>
#
#               </h4>
#               <div class="glue-zippy-content">
#                 <ul class="links-list">
#
#
#
# <li>
#   <a href="https://www.google.org"
# target="_blank"
#       data-g-category="footer"
#       data-g-action="responsibility"
#       data-g-label="Google.org"
#         data-g-href="https://www.google.org"
# >
# Google.org
#   </a>
# </li>
#
#
# <li>
#   <a href="https://sustainability.google"
# target="_blank"
#       data-g-category="footer"
#       data-g-action="responsibility"
#       data-g-label="Sustainability"
#         data-g-href="https://sustainability.google"
# >
# Sustainability
#   </a>
# </li>
#
#
# <li>
#   <a href="https://www.google.org/our-work/crisis-response/"
# target="_blank"
#       data-g-category="footer"
#       data-g-action="responsibility"
#       data-g-label="Crisis response"
#         data-g-href="https://www.google.org/our-work/crisis-response/"
# >
# Crisis Response
#   </a>
# </li>
#
#
# <li>
#   <a href="https://www.google.com/diversity/"
# target="_blank"
#       data-g-category="footer"
#       data-g-action="responsibility"
#       data-g-label="Diversity &amp; Inclusion"
#         data-g-href="https://www.google.com/diversity/"
# >
# Diversity &amp; Inclusion
#   </a>
# </li>
#
#
# <li>
#   <a href="https://www.google.com/accessibility/"
# target="_blank"
#       data-g-category="footer"
#       data-g-action="responsibility"
#       data-g-label="Accessibility"
#         data-g-href="https://www.google.com/accessibility/"
# >
# Accessibility
#   </a>
# </li>
#
#
# <li>
#   <a href="https://transparencyreport.google.com"
# target="_blank"
#       data-g-category="footer"
#       data-g-action="responsibility"
#       data-g-label="Transparency"
#         data-g-href="https://transparencyreport.google.com"
# >
# Transparency
#   </a>
# </li>
#
#
# <li>
#   <a href="https://wellbeing.google"
# target="_blank"
#       data-g-category="footer"
#       data-g-action="responsibility"
#       data-g-label="Digital Wellbeing"
#         data-g-href="https://wellbeing.google"
# >
# Digital Wellbeing
#   </a>
# </li>
#
#
# <li>
#   <a href="https://safety.google/"
# target="_blank"
#       data-g-category="footer"
#       data-g-action="responsibility"
#       data-g-label="Safety Center"
#         data-g-href="https://safety.google/"
# >
# Safety Center
#   </a>
# </li>                </ul>
#               </div>
#             </li>
#         </ul>
#       </section>
#       <section class="foot">
#         <h1 class="product-logo">
#           <a href="./" target="_self"              aria-label="Google"
#
#       data-g-category="footer"
#       data-g-action="navigation"
#       data-g-label="Logo"
#         data-g-href="/"
# >
#                 <svg alt="Google"  class="logo-svg " xmlns="http://www.w3.org/2000/svg" viewBox="0 0 86 28">
#     <path fill="#4285F4" d="M10.4,21C4.7,21,0,16.2,0,10.5S4.7,0,10.4,0c3.1,0,5.3,1.3,7,2.9l-1.9,2c-1.2-1.2-2.8-2-5-2
#       c-4.1,0-7.3,3.4-7.3,7.6s3.2,7.6,7.3,7.6c2.7,0,4.2-1.1,5.1-2.1c0.8-0.8,1.3-2,1.5-3.8h-6.6V9.3h9.3c0.1,0.5,0.2,1.1,0.2,1.8
#       c0,2.2-0.5,5-2.4,6.9C15.7,20,13.4,21,10.4,21z"/>
#     <path fill="#EA4335" d="M34.2,14.1c0,3.9-2.9,6.7-6.6,6.7s-6.6-2.8-6.6-6.7s2.9-6.7,6.6-6.7S34.2,10.2,34.2,14.1z M31.4,14.1
#       c0-2.5-1.7-4.1-3.7-4.1c-1.9,0-3.7,1.6-3.7,4.1c0,2.4,1.7,4.1,3.7,4.1C29.6,18.2,31.4,16.5,31.4,14.1z"/>
#     <path fill="#FBBC03" d="M48.4,14.1c0,3.9-2.9,6.7-6.6,6.7s-6.6-2.8-6.6-6.7s2.9-6.7,6.6-6.7S48.4,10.2,48.4,14.1z M45.5,14.1
#       c0-2.5-1.7-4.1-3.7-4.1c-1.9,0-3.7,1.6-3.7,4.1c0,2.4,1.7,4.1,3.7,4.1C43.8,18.2,45.5,16.5,45.5,14.1z"/>
#     <path fill="#4285F4" d="M61.7,7.8V20c0,5-2.7,7-6.1,7c-3.2,0-5-2.2-5.8-4l2.5-1.1c0.4,1.1,1.5,2.4,3.3,2.4c2.1,0,3.4-1.4,3.4-3.9v-1
#       h-0.1c-0.6,0.8-1.8,1.6-3.4,1.6c-3.3,0-6.2-2.9-6.2-6.8s2.9-6.7,6.2-6.7c1.6,0,2.7,0.7,3.4,1.6h0.1V7.8H61.7z M59.2,14.1
#       c0-2.4-1.5-4.1-3.5-4.1c-1.9,0-3.5,1.7-3.5,4.1s1.5,4.1,3.5,4.1C57.7,18.2,59.2,16.5,59.2,14.1z"/>
#     <path fill="#34A853" d="M66.4,1.1v19.8h-2.8V1.1H66.4z"/>
#     <path fill="#EA4335" d="M77.7,16.3l2.2,1.6c-0.7,1.1-2.5,3-5.5,3c-3.7,0-6.5-2.9-6.5-6.7c0-4,2.8-6.7,6.2-6.7c3.4,0,5,2.8,5.6,4.3
#       l0.3,0.7l-8.8,3.7c0.7,1.4,1.7,2,3.2,2S76.9,17.5,77.7,16.3z M70.8,14l5.8-2.5c-0.4-0.8-1.3-1.5-2.4-1.5C72.7,10,70.7,11.3,70.8,14
#       z"/>
#   </svg>
#
#           </a>
#         </h1>
#         <ul class="bottom-links">
#
#
#
# <li>
#   <a href="https://support.google.com?hl=en"
# target="_blank"
#       data-g-category="footer"
#       data-g-action="navigation"
#       data-g-label="Help"
#         data-g-href="https://support.google.com?hl=en"
# >
#         <svg alt=""  class="svg-icon" xmlns="http://www.w3.org/2000/svg" width="20px" height="20px" viewBox="0 0 24 24" fill="#000">
#     <path d="M0 0h24v24H0z" fill="none"/>
#     <path d="M12 2C6.48 2 2 6.48 2 12s4.48 10 10 10 10-4.48 10-10S17.52 2 12 2zm1 17h-2v-2h2v2zm2.07-7.75l-.9.92C13.45 12.9 13 13.5 13 15h-2v-.5c0-1.1.45-2.1 1.17-2.83l1.24-1.26c.37-.36.59-.86.59-1.41 0-1.1-.9-2-2-2s-2 .9-2 2H8c0-2.21 1.79-4 4-4s4 1.79 4 4c0 .88-.36 1.68-.93 2.25z"/>
#   </svg>
#
# Help
#   </a>
# </li>
#
#
# <li>
#   <a href="https://www.google.com/policies/privacy/"
# target="_blank"
#       data-g-category="footer"
#       data-g-action="navigation"
#       data-g-label="Privacy"
#         data-g-href="https://www.google.com/policies/privacy/"
# >
# Privacy
#   </a>
# </li>
#
#
# <li>
#   <a href="https://www.google.com/policies/terms/"
# target="_blank"
#       data-g-category="footer"
#       data-g-action="navigation"
#       data-g-label="Terms"
#         data-g-href="https://www.google.com/policies/terms/"
# >
# Terms
#   </a>
# </li>        </ul>
#       </section>
#     </div>
#   </div>
# </footer>
#       <div data-ui-view="modal" class="modal"></div>
#
#       <div class="progress" data-ng-if="mainCtrl.isLoading">
#         <span class="progress-bar progress-bar1"><!----></span>
#         <span class="progress-bar progress-bar2"><!----></span>
#       </div>
#
#
#
#
#
#       <!--[if gt IE 8]><!-->
# <script type="text/ng-template" id="/modal.html">
#   <div class="modal-overlay">
#     <div data-ui-view="modal-content" class="modal-content"></div>
#     <button class="glue-modal-close" aria-label="close" data-ng-click="modalStateCtrl.closeModal()">  <svg alt=""  class="icon icon-white" xmlns="http://www.w3.org/2000/svg" width="24px" height="24px" viewBox="0 0 24 24">
#     <path d="M7.41 18.59L8.83 20 12 16.83 15.17 20l1.41-1.41L12 14l-4.59 4.59zm9.18-13.18L15.17 4 12 7.17 8.83 4 7.41 5.41 12 10l4.59-4.59z"/>
#   </svg>
# </button>
#   </div>
# </script>
#
# <script type="text/ng-template" id="/glue/modal/modal-template.html">
#   <div>
#     <div class="glue-modal-overlay overlay-animate" data-glue-show="modalCtrl.getModalVisible()" data-ng-if="modalCtrl.getModalVisible()">
#       <div class="glue-modal" data-glue-show="modalCtrl.getModalVisible()" role="dialog" tabindex="-1">
#         <div class="glue-modal-content" data-ng-transclude></div>
#         <button class="glue-modal-close" aria-label="close">  <svg alt=""  class="icon icon-white" xmlns="http://www.w3.org/2000/svg" width="24px" height="24px" viewBox="0 0 24 24">
#     <path d="M7.41 18.59L8.83 20 12 16.83 15.17 20l1.41-1.41L12 14l-4.59 4.59zm9.18-13.18L15.17 4 12 7.17 8.83 4 7.41 5.41 12 10l4.59-4.59z"/>
#   </svg>
# </button>
#       </div>
#     </div>
#   </div>
# </script>        <script src="//www.gstatic.com/external_hosted/picturefill/picturefill.min.js"></script>
#         <script src="//ajax.googleapis.com/ajax/libs/angularjs/1.6.6/angular.min.js"></script>
#         <script src="//ajax.googleapis.com/ajax/libs/angularjs/1.6.6/angular-touch.min.js"></script>
#         <script src="//ajax.googleapis.com/ajax/libs/angularjs/1.6.6/angular-animate.min.js"></script>
#         <script src="//ajax.googleapis.com/ajax/libs/angularjs/1.6.6/angular-sanitize.min.js"></script>
#         <script src="//www.gstatic.com/external_hosted/ng_ui_router/release/angular-ui-router.min.js"></script>
#         <script src="//www.gstatic.com/external_hosted/gsap/v1_18_0/TweenMax.min.js"></script>
#         <script src="//www.gstatic.com/external_hosted/gsap/v1_18_0/plugins/ScrollToPlugin.min.js"></script>
#         <script src="//www.gstatic.com/external_hosted/scrollmagic/ScrollMagic.min.js"></script>
#         <script src="//www.gstatic.com/external_hosted/scrollmagic/animation.gsap.min.js"></script>
#         <script src="//www.gstatic.com/external_hosted/intersectionobserver_polyfill/intersection-observer.min.js"></script>
#         <script src="//www.gstatic.com/external_hosted/pixi/pixi.min.js"></script>
#         <script src="//www.google.com/jsapi"></script>
#         <script src="/assets/js/main.min.js?cache=41e9c04"></script>
#         <script src="/assets/js/detect.min.js?cache=08e8cf0"></script>
#       <!--<![endif]-->
#   </body>
# </html>

# %% [markdown]
# #### We could parse this ourselves, but fortunately scraping packages make this much easier
#
# We'll use Beautiful Soup's built in functionality to extract info on the individual offices.
#
# First, we parse the full site content.

# %%
site_content = soup(site_source.content, "html.parser")

type(site_content)
# Out:
# bs4.BeautifulSoup

# %% [markdown]
# Next, we pick out the office elements

# %%
offices = site_content.select(".office-info")

len(offices)
# Out:
# 156

# %%
site_content.select(".office-info")
# Out:
# [<div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Dubai
#                  </h2>
#  <div class="office-address" itemprop="address">TECOM Zone, Dubai Internet City
#  Dubai, United Arab Emirates</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+971 4 4509500" itemprop="telephone">
#                        +971 4 4509500
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/25.0929,55.1591?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Haifa
#                  </h2>
#  <div class="office-address" itemprop="address">Building 30
#  MATAM, Advanced Technology Center
#  Haifa, 3190500
#  Israel </div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+972-74-746-6245" itemprop="telephone">
#                        +972-74-746-6245
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/32.78897,34.958432?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Istanbul
#                  </h2>
#  <div class="office-address" itemprop="address">Eski Buyukdere Caddesi No: 209
#  34394
#  Istanbul, Turkey</div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/41.081697,29.00859?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Johannesburg
#                  </h2>
#  <div class="office-address" itemprop="address">35 Ballyclare Drive Building E
#  Johannesburg
#  2191, South Africa</div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/-26.0734457,28.032035?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Tel Aviv
#                  </h2>
#  <div class="office-address" itemprop="address">Yigal Alon 98
#  Tel Aviv, 6789141
#  Israel </div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+972-74-746-6453" itemprop="telephone">
#                        +972-74-746-6453
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/32.070043,34.794087?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Bangalore
#                  </h2>
#  <div class="office-address" itemprop="address">No. 3, RMZ Infinity - Tower E
#  Old Madras Road
#  4th and 5th Floors
#  Bangalore, 560 016, India</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+91-80-67218000" itemprop="telephone">
#                        +91-80-67218000
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/12.99332,77.660176?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Bangkok
#                  </h2>
#  <div class="office-address" itemprop="address">57 Park Ventures Ecoplex
#  14th Floor, Wireless Road
#  Bangkok, 10330, Thailand</div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/13.742866,100.547983?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Beijing
#                  </h2>
#  <div class="office-address" itemprop="address">6th Floor, Tower B, Raycom InfoTech Park
#  No. 2 Kexueyuan South Road
#  Zhongguancun Beijing 100190</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+86-10-62503000" itemprop="telephone">
#                        +86-10-62503000
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/39.9848878,116.3265708?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Guangzhou
#                  </h2>
#  <div class="office-address" itemprop="address">Taikoo Hui Tower 1, No.383 Tianhe Road
#  Guangzhou, 510620
#  China</div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/23.1339728,113.3332488?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Gurgaon
#                  </h2>
#  <div class="office-address" itemprop="address">Sector 15, Part II Village Silokhera
#  Gurgaon 122001
#  India</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+91-12-44512900" itemprop="telephone">
#                        +91-12-44512900
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/28.460581,77.048194?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Hong Kong
#                  </h2>
#  <div class="office-address" itemprop="address">1 Matheson Street
#  Causeway Bay, Hong Kong</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+852-3923-5400" itemprop="telephone">
#                        +852-3923-5400
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/22.278203,114.18176?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Hyderabad
#                  </h2>
#  <div class="office-address" itemprop="address">Survey No. 13, DivyaSree Omega
#  Kondapur Village
#  Hyderabad, Telangana 500084
#  India</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+91-40-6619-3000" itemprop="telephone">
#                        +91-40-6619-3000
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/17.458461,78.372452?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Jakarta
#                  </h2>
#  <div class="office-address" itemprop="address">Pacific Century Place Tower Level 45 SCBD Lot 10,
#  Jl. Jend. Sudirman No.53,
#  RT.5/RW.3, Senayan, Kby. Baru,
#  Kota Jakarta Selatan,
#  Daerah Khusus Ibukota Jakarta 12190,
#  Indonesia</div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/-6.227664,106.808471?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Kuala Lumpur
#                  </h2>
#  <div class="office-address" itemprop="address">Axiata Tower
#  No. 9, Jalan Stesen Sentral 5
#  50470 Kuala Lumpur
#  Malaysia</div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/3.133445,101.684609?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Melbourne
#                  </h2>
#  <div class="office-address" itemprop="address">161 Collins Street,
#  Melbourne VIC 3000,
#  Australia</div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/-37.815328,144.968737?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Mumbai
#                  </h2>
#  <div class="office-address" itemprop="address">3 North Avenue
#  Maker Maxity, Bandra Kurla Complex
#  Bandra East
#  Mumbai, Maharashtra 400051
#  India</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+91-22-6611-7150" itemprop="telephone">
#                        +91-22-6611-7150
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/19.054364,72.850591?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Seoul
#                  </h2>
#  <div class="office-address" itemprop="address">Google Korea LLC.
#  22nd Floor, Gangnam Finance Center
#  152 Teheran-ro, Gangnam-gu
#  Seoul 06236
#  South Korea</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+82-2-531-9000" itemprop="telephone">
#                        +82-2-531-9000
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/37.500295,127.036843?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Shanghai
#                  </h2>
#  <div class="office-address" itemprop="address">100 Century Avenue, Pudong
#  Shanghai 200120
#  China</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+86-21-6133-7666" itemprop="telephone">
#                        +86-21-6133-7666
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/31.23464,121.507662?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Singapore
#                  </h2>
#  <div class="office-address" itemprop="address">70 Pasir Panjang Road, #03-71,
#  Mapletree Business City
#  Singapore 117371</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+65 6521-8000" itemprop="telephone">
#                        +65 6521-8000
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/1.276466,103.798965?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Sydney
#                  </h2>
#  <div class="office-address" itemprop="address">48 Pirrama Road
#  Sydney, NSW 2009
#  Australia </div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+61 2 9374 4000" itemprop="telephone">
#                        +61 2 9374 4000
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/-33.866638,151.195672?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Taipei
#                  </h2>
#  <div class="office-address" itemprop="address">No. 7 XinYi Road Section 5, Taipei
#  Taiwan</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+886 2 8729 6000" itemprop="telephone">
#                        +886 2 8729 6000
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/25.033447,121.564901?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Tokyo
#                  </h2>
#  <div class="office-address" itemprop="address">Roppongi Hills Mori Tower
#  6-10-1 Roppongi
#  Minato-ku, Tokyo 106-6126
#  Japan</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+81-3-6384-9000" itemprop="telephone">
#                        +81-3-6384-9000
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/35.66047,139.729231?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Aarhus
#                  </h2>
#  <div class="office-address" itemprop="address">Aabogade 15
#  8200 Aarhus
#  Denmark</div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/56.172249,10.187372?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Amsterdam
#                  </h2>
#  <div class="office-address" itemprop="address">Claude Debussylaan 34
#  1082 MD, Amsterdam
#  Netherlands</div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/52.337801,4.872066?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Athens
#                  </h2>
#  <div class="office-address" itemprop="address">Fragkokklisias 7
#  Athens 151 25
#  Greece</div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/38.03902,23.804595?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Berlin
#                  </h2>
#  <div class="office-address" itemprop="address">Tucholskystraße 2
#  10117 Berlin
#  Germany</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+49 30 303986300" itemprop="telephone">
#                        +49 30 303986300
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/52.5231079,13.39203120000002?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Brussels
#                  </h2>
#  <div class="office-address" itemprop="address">Chaussee d'Etterbeek 180
#  1040 Brussels
#  Belgium</div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/50.839315,4.380984?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Copenhagen
#                  </h2>
#  <div class="office-address" itemprop="address">Skt. Petri Passage 5
#  1165 Copenhagen
#  Denmark</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+45 3370 2600" itemprop="telephone">
#                        +45 3370 2600
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/55.680452,12.570071?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Dublin
#                  </h2>
#  <div class="office-address" itemprop="address">Gordon House
#  Barrow St
#  Dublin 4
#  Ireland</div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/53.3399526,-6.2360967?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Hamburg
#                  </h2>
#  <div class="office-address" itemprop="address">ABC-Strasse 19
#  20354 Hamburg
#  Germany</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="49 40-80-81-79-000" itemprop="telephone">
#                        49 40-80-81-79-000
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/53.553752,9.986229?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Lisbon
#                  </h2>
#  <div class="office-address" itemprop="address">Avenida da Liberdade, 110
#  Lisbon, 1269-046, Portugal</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+351 21 122 1803" itemprop="telephone">
#                        +351 21 122 1803
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/38.718887,-9.143781?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    London - 6PS
#                  </h2>
#  <div class="office-address" itemprop="address">6 Pancras Square
#  London N1C 4AG
#  United Kingdom</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+44-20-7031-3000" itemprop="telephone">
#                        +44-20-7031-3000
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/51.533311,-0.126026?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    London - BEL
#                  </h2>
#  <div class="office-address" itemprop="address">Belgrave House
#  76 Buckingham Palace Road
#  London SW1W 9TQ
#  United Kingdom</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+44-20-7031-3001" itemprop="telephone">
#                        +44-20-7031-3001
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/51.494961,-0.146652?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    London - CSG
#                  </h2>
#  <div class="office-address" itemprop="address">1-13 St Giles High St
#  London WC2H 8AG
#  United Kingdom</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+44 (0)20-7031-3000" itemprop="telephone">
#                        +44 (0)20-7031-3000
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/51.516027,-0.12755?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Madrid
#                  </h2>
#  <div class="office-address" itemprop="address">Plaza Pablo Ruiz Picasso, I
#  Madrid 28020
#  Spain</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+34 91-748-6400" itemprop="telephone">
#                        +34 91-748-6400
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/40.4505331,-3.6931161?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Milan
#                  </h2>
#  <div class="office-address" itemprop="address">Porta Nuova Isola, Building C, Via Federico Confalonieri 4
#  20124 Milan
#  Italy</div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/45.486147,9.189546?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Moscow
#                  </h2>
#  <div class="office-address" itemprop="address">7 Balchug St
#  Moscow 115035
#  Russia</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+7-495-644-1400" itemprop="telephone">
#                        +7-495-644-1400
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/55.746747,37.626435?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Munich
#                  </h2>
#  <div class="office-address" itemprop="address">Erika-Mann-Str. 33
#  80636 Munich
#  Germany</div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/48.14305556,11.54083333?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Oslo
#                  </h2>
#  <div class="office-address" itemprop="address">Aker Brygge
#  Bryggegata 6
#  0250 Oslo
#  Norway</div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/59.90987,10.72598?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Paris
#                  </h2>
#  <div class="office-address" itemprop="address">8 Rue de Londres
#  75009 Paris
#  France</div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/48.8771,2.33?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Prague
#                  </h2>
#  <div class="office-address" itemprop="address">Stroupeznickeho str. 3191/17
#  Prague, Czech Republic
#  150 00</div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/50.070259,14.402642?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Stockholm
#                  </h2>
#  <div class="office-address" itemprop="address">Kungsbron 2
#  111 22 Stockholm
#  Sweden</div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/59.333432,18.054619?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Vienna
#                  </h2>
#  <div class="office-address" itemprop="address">Graben 19
#  1010 Wien
#  Austria</div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/48.209351,16.368419?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Warsaw
#                  </h2>
#  <div class="office-address" itemprop="address">Emilii Plater 53
#  00-113 Warsaw
#  Poland </div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+48 22 207 19 00" itemprop="telephone">
#                        +48 22 207 19 00
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/52.233448,21.001668?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Wroclaw
#                  </h2>
#  <div class="office-address" itemprop="address">Gen. Jozefa Bema nr 2
#  50-265 Wroclaw
#  Poland</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+48 (71) 73 41 000" itemprop="telephone">
#                        +48 (71) 73 41 000
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/51.117687,17.041737?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Zurich
#                  </h2>
#  <div class="office-address" itemprop="address">Brandschenkestrasse 110
#  8002 Zürich
#  Switzerland</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+41 44 668 18 00" itemprop="telephone">
#                        +41 44 668 18 00
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/47.365063,8.524425?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Belo Horizonte
#                  </h2>
#  <div class="office-address" itemprop="address">Boulevard Corporate Tower
#  Av. dos Andradas, 3000 - Andares 14-17
#  Santa Efigênia
#  Belo Horizonte
#  30260-070, Brazil</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+55-31-2128-6800" itemprop="telephone">
#                        +55-31-2128-6800
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/-19.920225,-43.920845?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Bogota
#                  </h2>
#  <div class="office-address" itemprop="address">Carrera 11A 94 - 45
#  Centro Empresarial Oxo Center
#  Bogota, Colombia</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+57 (1) 5939400" itemprop="telephone">
#                        +57 (1) 5939400
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/4.678267,-74.046901?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Buenos Aires
#                  </h2>
#  <div class="office-address" itemprop="address">Alicia M. De Justo 350, 2nd Floor
#  Buenos Aires, C1107AAH
#  Argentina</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+54-11-5530-3000" itemprop="telephone">
#                        +54-11-5530-3000
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/-34.602734,-58.366992?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Mexico City
#                  </h2>
#  <div class="office-address" itemprop="address">Google Mexico, S. de R.L. de C.V.
#  Montes Urales 445
#  Lomas de Chapultepec
#  Mexico City 11000, Mexico</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+52 55-5342-8400" itemprop="telephone">
#                        +52 55-5342-8400
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/19.4283793,-99.2065518?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Santiago
#                  </h2>
#  <div class="office-address" itemprop="address">Costanera Sur Rio 2730
#  Las Condes, Santiago
#  Chile</div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/-33.413383,-70.605665?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Sao Paulo
#                  </h2>
#  <div class="office-address" itemprop="address">Av. Brigadeiro Faria Lima, 3477
#  São Paulo
#  04538-133, Brazil</div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/-23.586479,-46.682078?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Ann Arbor
#                  </h2>
#  <div class="office-address" itemprop="address">2300 Traverwood Dr.
#  Ann Arbor, MI 48105
#  United States</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+1 734-332-6500" itemprop="telephone">
#                        +1 734-332-6500
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/42.3063848,-83.7140833?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Atlanta
#                  </h2>
#  <div class="office-address" itemprop="address">10 10th Street NE
#  Atlanta, GA 30309
#  United States</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+1 404-487-9000" itemprop="telephone">
#                        +1 404-487-9000
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/33.781827,-84.387301?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Austin
#                  </h2>
#  <div class="office-address" itemprop="address">500 W 2nd St
#  Suite 2900
#  Austin, TX 78701
#  United States</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+1 512-343-5283" itemprop="telephone">
#                        +1 512-343-5283
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/30.266035,-97.749237?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Boulder
#                  </h2>
#  <div class="office-address" itemprop="address">2600 Pearl Street
#  Boulder, CO 80302
#  United States</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+1 303-245-0086" itemprop="telephone">
#                        +1 303-245-0086
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/40.021693,-105.260139?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Cambridge
#                  </h2>
#  <div class="office-address" itemprop="address">355 Main Street
#  Cambridge, MA 02142
#  United States</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+1 617-575-1300" itemprop="telephone">
#                        +1 617-575-1300
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/42.362757,-71.087109?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Chapel Hill
#                  </h2>
#  <div class="office-address" itemprop="address">200 West Franklin Street
#  Chapel Hill, NC 27516
#  United States</div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/35.912445,-79.058488?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Chicago
#                  </h2>
#  <div class="office-address" itemprop="address">320 N. Morgan, Suite 600
#  Chicago, IL 60607
#  United States</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+1 312-840-4100" itemprop="telephone">
#                        +1 312-840-4100
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/41.8873457,-87.6526874?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Detroit
#                  </h2>
#  <div class="office-address" itemprop="address">52 Henry St.
#  3rd Floor
#  Detroit, MI 48201
#  United States</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+1 248-593-4003" itemprop="telephone">
#                        +1 248-593-4003
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/42.340458,-83.054494?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Irvine
#                  </h2>
#  <div class="office-address" itemprop="address">19510 Jamboree Road
#  Irvine, CA 92612
#  United States</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+1 949-794-1600" itemprop="telephone">
#                        +1 949-794-1600
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/33.658792,-117.859322?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Kirkland
#                  </h2>
#  <div class="office-address" itemprop="address">777 6th Street South
#  Kirkland, WA
#  United States</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+1 425-739-5600" itemprop="telephone">
#                        +1 425-739-5600
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/47.669568,-122.196912?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Kitchener
#                  </h2>
#  <div class="office-address" itemprop="address">51 Breithaupt Street
#  Kitchener, ON N2H 5G5
#  Canada</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+1-519-880-2300" itemprop="telephone">
#                        +1-519-880-2300
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/43.4541137,-80.4992423?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Los Angeles
#                  </h2>
#  <div class="office-address" itemprop="address">340 Main Street
#  Los Angeles, CA 90291
#  United States</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+1 310-310-6000" itemprop="telephone">
#                        +1 310-310-6000
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/33.995939,-118.4766773?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Miami
#                  </h2>
#  <div class="office-address" itemprop="address">1450 Brickell Ave Ste 900
#  Miami FL 33131
#  United States</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+1 305-985-7900" itemprop="telephone">
#                        +1 305-985-7900
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/25.758473,-80.1932144?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Montreal
#                  </h2>
#  <div class="office-address" itemprop="address">1253 McGill College Avenue
#  Montreal, QC H3B 2Y5
#  Canada</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="514-670-8700" itemprop="telephone">
#                        514-670-8700
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/45.50191,-73.570365?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Mountain View
#                  </h2>
#  <div class="office-address" itemprop="address">1600 Amphitheatre Parkway
#  Mountain View, CA 94043
#  United States</div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/37.421512,-122.084101?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    New York
#                  </h2>
#  <div class="office-address" itemprop="address">111 8th Avenue
#  New York, NY 10011
#  United States</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+1 212-565-0000" itemprop="telephone">
#                        +1 212-565-0000
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/40.741445,-74.003102?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Pittsburgh
#                  </h2>
#  <div class="office-address" itemprop="address">6425 Penn Avenue
#  Pittsburgh, PA 15206
#  United States</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+1 412-345-6700" itemprop="telephone">
#                        +1 412-345-6700
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/40.45716,-79.916596?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Playa Vista
#                  </h2>
#  <div class="office-address" itemprop="address">12422 W. Bluff Creek Drive
#  Playa Vista, CA 90094
#  United States</div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/33.97684,-118.407244?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Reston
#                  </h2>
#  <div class="office-address" itemprop="address">1875 Explorer Street
#  10th Floor
#  Reston, VA 20190
#  United States</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+1 202-370-5600" itemprop="telephone">
#                        +1 202-370-5600
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/38.958309,-77.359795?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    San Bruno
#                  </h2>
#  <div class="office-address" itemprop="address">901 Cherry Avenue
#  San Bruno, CA 94066
#  United States</div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/37.62816,-122.426491?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    San Diego
#                  </h2>
#  <div class="office-address" itemprop="address">6420 Sequence Dr
#  Suite 400
#  San Diego, CA 92121
#  United States</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+1 858-239-4000" itemprop="telephone">
#                        +1 858-239-4000
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/32.909610,-117.181899?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    San Francisco
#                  </h2>
#  <div class="office-address" itemprop="address">345 Spear Street
#  San Francisco, CA 94105
#  United States</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+1 415-736-0000" itemprop="telephone">
#                        +1 415-736-0000
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/37.789972,-122.390013?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Seattle
#                  </h2>
#  <div class="office-address" itemprop="address">601 N. 34th Street
#  Seattle, WA 98103
#  United States</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="+1 206-876-1800" itemprop="telephone">
#                        +1 206-876-1800
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/47.649316,-122.350629?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Sunnyvale
#                  </h2>
#  <div class="office-address" itemprop="address">803 11th Avenue
#  Sunnyvale, CA 94089
#  United States</div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/37.403694,-122.031583?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Toronto
#                  </h2>
#  <div class="office-address" itemprop="address">111 Richmond Street West
#  Toronto, ON M5H 2G4
#  Canada</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number="416-915-8200" itemprop="telephone">
#                        416-915-8200
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/43.650477,-79.383858?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                    Washington DC
#                  </h2>
#  <div class="office-address" itemprop="address">25 Massachusetts Avenue
#  Washington DC, 20001
#  United States</div>
#  <div class="office-phone-number">
#                      Phone:
#                      <span class="phone-number" data-phone-number=" (202) 346-1100" itemprop="telephone">
#                         (202) 346-1100
#                      </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/38.898337,-77.010286?hl=en" rel="noopener" target="_blank">
#                      Directions
#                    </a>
#  </div>
#  </div>, <div class="office-info">
# ...
#  <div class="office-address" itemprop="address">Emilii Plater 53
#  00-113 Warsaw
#  Poland </div>
#  <div>
#                          Phone:
#                          <span class="phone-number" data-phone-number="+48 22 207 19 00" itemprop="telephone">
#                            +48 22 207 19 00
#                          </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/52.233448,21.001668?hl=en" rel="noopener" target="_blank">
#                          Directions
#                        </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                        Wroclaw
#                      </h2>
#  <div class="office-address" itemprop="address">Gen. Jozefa Bema nr 2
#  50-265 Wroclaw
#  Poland</div>
#  <div>
#                          Phone:
#                          <span class="phone-number" data-phone-number="+48 (71) 73 41 000" itemprop="telephone">
#                            +48 (71) 73 41 000
#                          </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/51.117687,17.041737?hl=en" rel="noopener" target="_blank">
#                          Directions
#                        </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                        Zurich
#                      </h2>
#  <div class="office-address" itemprop="address">Brandschenkestrasse 110
#  8002 Zürich
#  Switzerland</div>
#  <div>
#                          Phone:
#                          <span class="phone-number" data-phone-number="+41 44 668 18 00" itemprop="telephone">
#                            +41 44 668 18 00
#                          </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/47.365063,8.524425?hl=en" rel="noopener" target="_blank">
#                          Directions
#                        </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                        Bangalore
#                      </h2>
#  <div class="office-address" itemprop="address">No. 3, RMZ Infinity - Tower E
#  Old Madras Road
#  4th and 5th Floors
#  Bangalore, 560 016, India</div>
#  <div>
#                          Phone:
#                          <span class="phone-number" data-phone-number="+91-80-67218000" itemprop="telephone">
#                            +91-80-67218000
#                          </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/12.99332,77.660176?hl=en" rel="noopener" target="_blank">
#                          Directions
#                        </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                        Bangkok
#                      </h2>
#  <div class="office-address" itemprop="address">57 Park Ventures Ecoplex
#  14th Floor, Wireless Road
#  Bangkok, 10330, Thailand</div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/13.742866,100.547983?hl=en" rel="noopener" target="_blank">
#                          Directions
#                        </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                        Beijing
#                      </h2>
#  <div class="office-address" itemprop="address">6th Floor, Tower B, Raycom InfoTech Park
#  No. 2 Kexueyuan South Road
#  Zhongguancun Beijing 100190</div>
#  <div>
#                          Phone:
#                          <span class="phone-number" data-phone-number="+86-10-62503000" itemprop="telephone">
#                            +86-10-62503000
#                          </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/39.9848878,116.3265708?hl=en" rel="noopener" target="_blank">
#                          Directions
#                        </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                        Guangzhou
#                      </h2>
#  <div class="office-address" itemprop="address">Taikoo Hui Tower 1, No.383 Tianhe Road
#  Guangzhou, 510620
#  China</div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/23.1339728,113.3332488?hl=en" rel="noopener" target="_blank">
#                          Directions
#                        </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                        Gurgaon
#                      </h2>
#  <div class="office-address" itemprop="address">Sector 15, Part II Village Silokhera
#  Gurgaon 122001
#  India</div>
#  <div>
#                          Phone:
#                          <span class="phone-number" data-phone-number="+91-12-44512900" itemprop="telephone">
#                            +91-12-44512900
#                          </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/28.460581,77.048194?hl=en" rel="noopener" target="_blank">
#                          Directions
#                        </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                        Hong Kong
#                      </h2>
#  <div class="office-address" itemprop="address">1 Matheson Street
#  Causeway Bay, Hong Kong</div>
#  <div>
#                          Phone:
#                          <span class="phone-number" data-phone-number="+852-3923-5400" itemprop="telephone">
#                            +852-3923-5400
#                          </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/22.278203,114.18176?hl=en" rel="noopener" target="_blank">
#                          Directions
#                        </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                        Hyderabad
#                      </h2>
#  <div class="office-address" itemprop="address">Survey No. 13, DivyaSree Omega
#  Kondapur Village
#  Hyderabad, Telangana 500084
#  India</div>
#  <div>
#                          Phone:
#                          <span class="phone-number" data-phone-number="+91-40-6619-3000" itemprop="telephone">
#                            +91-40-6619-3000
#                          </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/17.458461,78.372452?hl=en" rel="noopener" target="_blank">
#                          Directions
#                        </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                        Jakarta
#                      </h2>
#  <div class="office-address" itemprop="address">Pacific Century Place Tower Level 45 SCBD Lot 10,
#  Jl. Jend. Sudirman No.53,
#  RT.5/RW.3, Senayan, Kby. Baru,
#  Kota Jakarta Selatan,
#  Daerah Khusus Ibukota Jakarta 12190,
#  Indonesia</div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/-6.227664,106.808471?hl=en" rel="noopener" target="_blank">
#                          Directions
#                        </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                        Kuala Lumpur
#                      </h2>
#  <div class="office-address" itemprop="address">Axiata Tower
#  No. 9, Jalan Stesen Sentral 5
#  50470 Kuala Lumpur
#  Malaysia</div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/3.133445,101.684609?hl=en" rel="noopener" target="_blank">
#                          Directions
#                        </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                        Melbourne
#                      </h2>
#  <div class="office-address" itemprop="address">161 Collins Street,
#  Melbourne VIC 3000,
#  Australia</div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/-37.815328,144.968737?hl=en" rel="noopener" target="_blank">
#                          Directions
#                        </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                        Mumbai
#                      </h2>
#  <div class="office-address" itemprop="address">3 North Avenue
#  Maker Maxity, Bandra Kurla Complex
#  Bandra East
#  Mumbai, Maharashtra 400051
#  India</div>
#  <div>
#                          Phone:
#                          <span class="phone-number" data-phone-number="+91-22-6611-7150" itemprop="telephone">
#                            +91-22-6611-7150
#                          </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/19.054364,72.850591?hl=en" rel="noopener" target="_blank">
#                          Directions
#                        </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                        Seoul
#                      </h2>
#  <div class="office-address" itemprop="address">Google Korea LLC.
#  22nd Floor, Gangnam Finance Center
#  152 Teheran-ro, Gangnam-gu
#  Seoul 06236
#  South Korea</div>
#  <div>
#                          Phone:
#                          <span class="phone-number" data-phone-number="+82-2-531-9000" itemprop="telephone">
#                            +82-2-531-9000
#                          </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/37.500295,127.036843?hl=en" rel="noopener" target="_blank">
#                          Directions
#                        </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                        Shanghai
#                      </h2>
#  <div class="office-address" itemprop="address">100 Century Avenue, Pudong
#  Shanghai 200120
#  China</div>
#  <div>
#                          Phone:
#                          <span class="phone-number" data-phone-number="+86-21-6133-7666" itemprop="telephone">
#                            +86-21-6133-7666
#                          </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/31.23464,121.507662?hl=en" rel="noopener" target="_blank">
#                          Directions
#                        </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                        Singapore
#                      </h2>
#  <div class="office-address" itemprop="address">70 Pasir Panjang Road, #03-71,
#  Mapletree Business City
#  Singapore 117371</div>
#  <div>
#                          Phone:
#                          <span class="phone-number" data-phone-number="+65 6521-8000" itemprop="telephone">
#                            +65 6521-8000
#                          </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/1.276466,103.798965?hl=en" rel="noopener" target="_blank">
#                          Directions
#                        </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                        Sydney
#                      </h2>
#  <div class="office-address" itemprop="address">48 Pirrama Road
#  Sydney, NSW 2009
#  Australia </div>
#  <div>
#                          Phone:
#                          <span class="phone-number" data-phone-number="+61 2 9374 4000" itemprop="telephone">
#                            +61 2 9374 4000
#                          </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/-33.866638,151.195672?hl=en" rel="noopener" target="_blank">
#                          Directions
#                        </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                        Taipei
#                      </h2>
#  <div class="office-address" itemprop="address">No. 7 XinYi Road Section 5, Taipei
#  Taiwan</div>
#  <div>
#                          Phone:
#                          <span class="phone-number" data-phone-number="+886 2 8729 6000" itemprop="telephone">
#                            +886 2 8729 6000
#                          </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/25.033447,121.564901?hl=en" rel="noopener" target="_blank">
#                          Directions
#                        </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                        Tokyo
#                      </h2>
#  <div class="office-address" itemprop="address">Roppongi Hills Mori Tower
#  6-10-1 Roppongi
#  Minato-ku, Tokyo 106-6126
#  Japan</div>
#  <div>
#                          Phone:
#                          <span class="phone-number" data-phone-number="+81-3-6384-9000" itemprop="telephone">
#                            +81-3-6384-9000
#                          </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/35.66047,139.729231?hl=en" rel="noopener" target="_blank">
#                          Directions
#                        </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                        Dubai
#                      </h2>
#  <div class="office-address" itemprop="address">TECOM Zone, Dubai Internet City
#  Dubai, United Arab Emirates</div>
#  <div>
#                          Phone:
#                          <span class="phone-number" data-phone-number="+971 4 4509500" itemprop="telephone">
#                            +971 4 4509500
#                          </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/25.0929,55.1591?hl=en" rel="noopener" target="_blank">
#                          Directions
#                        </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                        Haifa
#                      </h2>
#  <div class="office-address" itemprop="address">Building 30
#  MATAM, Advanced Technology Center
#  Haifa, 3190500
#  Israel </div>
#  <div>
#                          Phone:
#                          <span class="phone-number" data-phone-number="+972-74-746-6245" itemprop="telephone">
#                            +972-74-746-6245
#                          </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/32.78897,34.958432?hl=en" rel="noopener" target="_blank">
#                          Directions
#                        </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                        Istanbul
#                      </h2>
#  <div class="office-address" itemprop="address">Eski Buyukdere Caddesi No: 209
#  34394
#  Istanbul, Turkey</div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/41.081697,29.00859?hl=en" rel="noopener" target="_blank">
#                          Directions
#                        </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                        Johannesburg
#                      </h2>
#  <div class="office-address" itemprop="address">35 Ballyclare Drive Building E
#  Johannesburg
#  2191, South Africa</div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/-26.0734457,28.032035?hl=en" rel="noopener" target="_blank">
#                          Directions
#                        </a>
#  </div>
#  </div>, <div class="office-info">
#  <h2 class="office-name" itemprop="name">
#                        Tel Aviv
#                      </h2>
#  <div class="office-address" itemprop="address">Yigal Alon 98
#  Tel Aviv, 6789141
#  Israel </div>
#  <div>
#                          Phone:
#                          <span class="phone-number" data-phone-number="+972-74-746-6453" itemprop="telephone">
#                            +972-74-746-6453
#                          </span>
#  </div>
#  <div class="directions">
#  <a href="https://www.google.com/maps/dir/Current+Location/32.070043,34.794087?hl=en" rel="noopener" target="_blank">
#                          Directions
#                        </a>
#  </div>
#  </div>]

# %% [markdown]
# Now that we've isolated the office elements, let's extract the location name and address for each.

# %%
countries = []
for o in offices:
    office = o.select(".office-name")[0].string.strip()
    address = o.select(".office-address")[0].string.strip()
    
    address_list = re.split(r'\n|\,', address)
    country = address_list[-1].strip()
    if country not in countries:
        countries.append(country)
        print(country)
        
    print()
# Out:
# United Arab Emirates
#
# Israel
#
# Turkey
#
# South Africa
#
#
# India
#
# Thailand
#
# Zhongguancun Beijing 100190
#
# China
#
#
# Hong Kong
#
#
# Indonesia
#
# Malaysia
#
# Australia
#
#
# South Korea
#
#
# Singapore 117371
#
#
# Taiwan
#
# Japan
#
# Denmark
#
# Netherlands
#
# Greece
#
# Germany
#
# Belgium
#
#
# Ireland
#
#
# Portugal
#
# United Kingdom
#
#
#
# Spain
#
# Italy
#
# Russia
#
#
# Norway
#
# France
#
# 150 00
#
# Sweden
#
# Austria
#
# Poland
#
#
# Switzerland
#
# Brazil
#
# Colombia
#
# Argentina
#
# Mexico
#
# Chile
#
#
# United States
#
#
#
#
#
#
#
#
#
#
# Canada

# %%
countries
# Out:
# ['United Arab Emirates',
#  'Israel',
#  'Turkey',
#  'South Africa',
#  'India',
#  'Thailand',
#  'Zhongguancun Beijing 100190',
#  'China',
#  'Hong Kong',
#  'Indonesia',
#  'Malaysia',
#  'Australia',
#  'South Korea',
#  'Singapore 117371',
#  'Taiwan',
#  'Japan',
#  'Denmark',
#  'Netherlands',
#  'Greece',
#  'Germany',
#  'Belgium',
#  'Ireland',
#  'Portugal',
#  'United Kingdom',
#  'Spain',
#  'Italy',
#  'Russia',
#  'Norway',
#  'France',
#  '150 00',
#  'Sweden',
#  'Austria',
#  'Poland',
#  'Switzerland',
#  'Brazil',
#  'Colombia',
#  'Argentina',
#  'Mexico',
#  'Chile',
#  'United States',
#  'Canada']

# %% [markdown]
# #### If we look carefully at our extracted elements, we'll see we have some issues:
# 1. All elements appear twice.
# 2. The zip codes - which we're interested in - are part of broader strings.
#
# These are trivial to handle, we'll just need to pass over the data carefully to handle both.

# %%
us_offices = []
for o in offices:
    office = o.select(".office-name")[0].string.strip()
    address = o.select(".office-address")[0].string.strip()

    is_US = re.search(r'(United States)', address)

    if is_US:
        
        print(office)
        zip_code = re.search(r'(\d{5})', address)
        if zip_code:
            print(zip_code.group())
            if [office, zip_code.group()] not in us_offices:
                us_offices.append([office, zip_code.group()])
        print()
# Out:
# Ann Arbor
# 48105
#
# Atlanta
# 30309
#
# Austin
# 78701
#
# Boulder
# 80302
#
# Cambridge
# 02142
#
# Chapel Hill
# 27516
#
# Chicago
# 60607
#
# Detroit
# 48201
#
# Irvine
# 19510
#
# Kirkland
#
# Los Angeles
# 90291
#
# Miami
# 33131
#
# Mountain View
# 94043
#
# New York
# 10011
#
# Pittsburgh
# 15206
#
# Playa Vista
# 12422
#
# Reston
# 20190
#
# San Bruno
# 94066
#
# San Diego
# 92121
#
# San Francisco
# 94105
#
# Seattle
# 98103
#
# Sunnyvale
# 94089
#
# Washington DC
# 20001
#
# Ann Arbor
# 48105
#
# Atlanta
# 30309
#
# Austin
# 78701
#
# Boulder
# 80302
#
# Cambridge
# 02142
#
# Chapel Hill
# 27516
#
# Chicago
# 60607
#
# Detroit
# 48201
#
# Irvine
# 19510
#
# Kirkland
#
# Los Angeles
# 90291
#
# Miami
# 33131
#
# Mountain View
# 94043
#
# New York
# 10011
#
# Pittsburgh
# 15206
#
# Playa Vista
# 12422
#
# Reston
# 20190
#
# San Bruno
# 94066
#
# San Diego
# 92121
#
# San Francisco
# 94105
#
# Seattle
# 98103
#
# Sunnyvale
# 94089
#
# Washington DC
# 20001

# %% [markdown]
# Now that we've extracted a list of offices and zip codes, we can load them into a data frame.

# %%
office_df = pd.DataFrame(us_offices, columns=['Office', 'Zip Code'])

office_df
# Out:
#            Office Zip Code
# 0       Ann Arbor    48105
# 1         Atlanta    30309
# 2          Austin    78701
# 3         Boulder    80302
# 4       Cambridge    02142
# 5     Chapel Hill    27516
# 6         Chicago    60607
# 7         Detroit    48201
# 8          Irvine    19510
# 9     Los Angeles    90291
# 10          Miami    33131
# 11  Mountain View    94043
# 12       New York    10011
# 13     Pittsburgh    15206
# 14    Playa Vista    12422
# 15         Reston    20190
# 16      San Bruno    94066
# 17      San Diego    92121
# 18  San Francisco    94105
# 19        Seattle    98103
# 20      Sunnyvale    94089
# 21  Washington DC    20001

# %% [markdown]
# ## Exercise: In What Countries Does Google Maintain Offices?

# %% [markdown]
# ## Adding County Information
#
# The Department of Housing and Urban Development makes a *crosswalk* of zip codes to counties available [here](https://www.huduser.gov/portal/datasets/usps_crosswalk.html). We can load these into pandas and clean them up to find the county for each office.

# %%
zip_df = pd.read_csv('https://grantmlong.com/data/ZIP_COUNTY_122016.csv')

zip_df.head(5)
# Out:
#    ZIP  COUNTY  RES_RATIO  BUS_RATIO  OTH_RATIO  TOT_RATIO
# 0  501   36103   0.000000   1.000000   0.000000   1.000000
# 1  601   72001   1.000000   1.000000   1.000000   1.000000
# 2  602   72003   1.000000   1.000000   1.000000   1.000000
# 3  603   72071   0.008258   0.000948   0.007767   0.007841
# 4  603   72005   0.991742   0.999052   0.992233   0.992159

# %% [markdown]
# #### A good rule of thumb: if two numbers cannot be added together to produce a logical result, they should be stored as strings. '
#
# We can recast the zip and county ids as strings - with leading zeros - to make this dataframe easier to handle. To do this we can use the [.astype()](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.astype.html) and [.zfill()](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.str.zfill.html) methods.

# %%
zip_df['Zip Code'] = zip_df['ZIP'].astype(str).str.zfill(5) 
zip_df['County Number'] = zip_df['COUNTY'].astype(str).str.zfill(5) 

zip_df.sort_values(by='COUNTY').head(5)
# Out:
#          ZIP  COUNTY  RES_RATIO  BUS_RATIO  OTH_RATIO  TOT_RATIO Zip Code  \
# 18372  36758    1001   0.200739   0.083333   0.000000   0.197133    36758
# 18029  36091    1001   0.096154   0.076923   0.000000   0.095303    36091
# 18008  36068    1001   1.000000   1.000000   1.000000   1.000000    36068
# 18006  36067    1001   1.000000   0.997963   1.000000   0.999856    36067
# 18005  36066    1001   0.879960   0.703650   0.677686   0.860627    36066
#
#       County Number
# 18372         01001
# 18029         01001
# 18008         01001
# 18006         01001
# 18005         01001

# %% [markdown]
# Of course we don't need all of these columns, but we do need to attach the ***County Number*** column to our Google office data in order to learn more about the data. The [.merge()](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.merge.html) method allows us to do this easily in one line.

# %%
office_df = office_df.merge(zip_df[['Zip Code', 'County Number']], 
                            how='left')

office_df.sort_values(by='Office')
office_df.shape
# Out:
# (23, 3)

# %%
office_df.sort_values(by='County Number')
# Out:
#            Office Zip Code County Number
# 10    Los Angeles    90291         06037
# 18      San Diego    92121         06073
# 19  San Francisco    94105         06075
# 17      San Bruno    94066         06081
# 12  Mountain View    94043         06085
# 21      Sunnyvale    94089         06085
# 3         Boulder    80302         08013
# 22  Washington DC    20001         11001
# 11          Miami    33131         12086
# 1         Atlanta    30309         13121
# 7         Chicago    60607         17031
# 4       Cambridge    02142         25017
# 0       Ann Arbor    48105         26161
# 8         Detroit    48201         26163
# 15    Playa Vista    12422         36039
# 13       New York    10011         36061
# 5     Chapel Hill    27516         37037
# 6     Chapel Hill    27516         37135
# 14     Pittsburgh    15206         42003
# 9          Irvine    19510         42011
# 2          Austin    78701         48453
# 16         Reston    20190         51059
# 20        Seattle    98103         53033

# %% [markdown]
# ### Merge Office Data with Census Data
# First, we'll need to load the data extract we produced in the first data dive. We'll also need to make sure that the *County Number* - the variable we need to join our data on - is appropriately formatted as a string.

# %%
census_df = pd.read_csv('https://grantmlong.com/data/census_counties_backup.csv')
census_df['County Number'] = census_df['County Number'].astype(str).str.zfill(5) 

census_df.head(5)
# Out:
#                County Name  Total Population  Median Household Income  \
# 0  Autauga County, Alabama             55049                    53099
# 1  Baldwin County, Alabama            199510                    51365
# 2  Barbour County, Alabama             26614                    33956
# 3     Bibb County, Alabama             22572                    39776
# 4   Blount County, Alabama             57704                    46212
#
#    Median Rent County Number
# 0          731         01001
# 1          712         01003
# 2          379         01005
# 3          430         01007
# 4          432         01009

# %% [markdown]
# Next, we'll use the [.merge()](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.merge.html) method to attach the two data sets.

# %%
full_df = census_df.merge(office_df, how='left')
full_df.loc[full_df['Office'].notnull(), ].head(5)
# Out:
#                           County Name  Total Population  \
# 204    Los Angeles County, California          10057155
# 222      San Diego County, California           3253356
# 223  San Francisco County, California            850282
# 226      San Mateo County, California            754748
# 228    Santa Clara County, California           1885056
#
#      Median Household Income  Median Rent County Number         Office  \
# 204                    57952         1167         06037    Los Angeles
# 222                    66529         1307         06073      San Diego
# 223                    87701         1573         06075  San Francisco
# 226                    98546         1744         06081      San Bruno
# 228                   101173         1727         06085  Mountain View
#
#     Zip Code
# 204    90291
# 222    92121
# 223    94105
# 226    94066
# 228    94043

# %% [markdown]
# #### With our full data set, we can now begin to look at some interesting numbers, like the median income in counties where google has an office, and where they don't.

# %%
print(full_df['Median Rent'].mean())
print(full_df.loc[full_df['Office'].notnull(), 'Median Rent'].mean())
print(full_df.loc[full_df['Office'].isnull(), 'Median Rent'].mean())
# Out:
# -206432.4129152437
# 1123.7826086956522
# -207925.15603502188

# %%
(full_df.loc[full_df['Office'].notnull(),]
 .sort_values(by='Median Rent', 
              ascending=False)
 .head(50))
# Out:
#                                      County Name  Total Population  \
# 226                 San Mateo County, California            754748
# 228               Santa Clara County, California           1885056
# 229               Santa Clara County, California           1885056
# 2849                    Fairfax County, Virginia           1132887
# 223             San Francisco County, California            850282
# 1859                   New York County, New York           1634989
# 222                 San Diego County, California           3253356
# 320   District of Columbia, District of Columbia            659009
# 1226             Middlesex County, Massachusetts           1567610
# 204               Los Angeles County, California          10057155
# 2970                     King County, Washington           2079550
# 251                     Boulder County, Colorado            313961
# 363                   Miami-Dade County, Florida           2664418
# 2750                        Travis County, Texas           1148176
# 611                        Cook County, Illinois           5227575
# 1312                  Washtenaw County, Michigan            358082
# 447                       Fulton County, Georgia            996757
# 1958               Orange County, North Carolina            139807
# 2250                  Berks County, Pennsylvania            414097
# 1848                     Greene County, New York             48069
# 2246              Allegheny County, Pennsylvania           1230360
# 1313                      Wayne County, Michigan           1767593
# 1909              Chatham County, North Carolina             68778
#
#       Median Household Income  Median Rent County Number         Office  \
# 226                     98546         1744         06081      San Bruno
# 228                    101173         1727         06085  Mountain View
# 229                    101173         1727         06085      Sunnyvale
# 2849                   114329         1659         51059         Reston
# 223                     87701         1573         06075  San Francisco
# 1859                    75513         1488         36061       New York
# 222                     66529         1307         06073      San Diego
# 320                     72935         1264         11001  Washington DC
# 1226                    89019         1257         25017      Cambridge
# 204                     57952         1167         06037    Los Angeles
# 2970                    78800         1149         53033        Seattle
# 251                     72282         1146         08013        Boulder
# 363                     44224         1000         12086          Miami
# 2750                    64422          941         48453         Austin
# 611                     56902          883         17031        Chicago
# 1312                    62484          868         26161      Ann Arbor
# 447                     58851          854         13121        Atlanta
# 1958                    61130          838         37135    Chapel Hill
# 2250                    57068          692         42011         Irvine
# 1848                    51013          665         36039    Playa Vista
# 2246                    54357          654         42003     Pittsburgh
# 1313                    42043          632         26163        Detroit
# 1909                    58555          612         37037    Chapel Hill
#
#      Zip Code
# 226     94066
# 228     94043
# 229     94089
# 2849    20190
# 223     94105
# 1859    10011
# 222     92121
# 320     20001
# 1226    02142
# 204     90291
# 2970    98103
# 251     80302
# 363     33131
# 2750    78701
# 611     60607
# 1312    48105
# 447     30309
# 1958    27516
# 2250    19510
# 1848    12422
# 2246    15206
# 1313    48201
# 1909    27516

# %% [markdown]
# ## Exercise: What Other Interesting Findings Can We Identify?
