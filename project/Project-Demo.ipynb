# %% [markdown]
# # Project Demo
#
# This demo is designed to provide some general tips and tricks for the ITDS Fall 2019 project. For full details on the project, please refer to [the project requirements](https://grantmlong.com/teaching/fall2019/project/Project-ITDS-Fall-2019.pdf).
#
# ***
# This demo uses `scikit-learn`, but by no means are you required to use this or any other particular package.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

from sklearn.ensemble import RandomForestRegressor

# %matplotlib inline

# %%
import helpers

# %%
train_df = pd.read_csv('https://grantmlong.com/data/SE_rents2018_train.csv', index_col=0)
test_df = pd.read_csv('https://grantmlong.com/data/SE_rents2018_test1.csv', index_col=0)
submit1_df = pd.read_csv('https://grantmlong.com/data/SE_rents2018_test2.csv', index_col=0)
submit2_df = pd.read_csv('https://grantmlong.com/data/SE_rents2018_test3.csv', index_col=0)

# %%
train_df.sample(5).transpose()
# Out:
# rental_id                                                         7153300  \
# addr_unit                                                             #3B
# building_id                                                        745084
# bedrooms                                                                2
# bathrooms                                                               1
# size_sqft                                                            1078
# created_at                                            2018-05-07 12:43:54
# addr_street                                           1255 EAST 19 STREET
# addr_city                                                        Brooklyn
# addr_zip                                                            11230
# addr_lat                                                          40.6196
# addr_lon                                                          -73.956
# bin                                                           3.18073e+06
# bbl                                                            3067390019
# floor_count                                                            11
# year_built                                                           1959
# min_to_subway                                                      2.6167
# has_doorman                                                             1
# has_elevator                                                            1
# has_fireplace                                                           0
# has_dishwasher                                                          1
# is_furnished                                                            0
# has_gym                                                                 0
# allows_pets                                                             0
# has_washer_dryer                                                        1
# has_garage                                                              0
# has_roofdeck                                                            0
# has_concierge                                                           0
# has_pool                                                                0
# has_garden                                                              0
# has_childrens_playroom                                                  0
# rent                                                                 2600
# no_fee                                                                  0
# description             Experience the finest luxury living! Situated ...
# neighborhood                                                      Midwood
# borough                                                          Brooklyn
# unit                                                                   3B
# floornumber                                                             3
# line                                                                    B
#
# rental_id                                                         7321309  \
# addr_unit                                                              #1
# building_id                                                        518503
# bedrooms                                                                2
# bathrooms                                                               2
# size_sqft                                                             900
# created_at                                            2018-06-29 19:17:43
# addr_street                                            518 MIDWOOD STREET
# addr_city                                                        Brooklyn
# addr_zip                                                            11225
# addr_lat                                                          40.6603
# addr_lon                                                         -73.9435
# bin                                                           3.25304e+06
# bbl                                                            3048030032
# floor_count                                                             3
# year_built                                                           2004
# min_to_subway                                                      5.2333
# has_doorman                                                             0
# has_elevator                                                            0
# has_fireplace                                                           0
# has_dishwasher                                                          0
# is_furnished                                                            0
# has_gym                                                                 0
# allows_pets                                                             0
# has_washer_dryer                                                        0
# has_garage                                                              0
# has_roofdeck                                                            0
# has_concierge                                                           0
# has_pool                                                                0
# has_garden                                                              0
# has_childrens_playroom                                                  0
# rent                                                                 2800
# no_fee                                                                  0
# description             Be happy to come home! This rental features tw...
# neighborhood                                                East Flatbush
# borough                                                          Brooklyn
# unit                                                                    1
# floornumber                                                             1
# line                                                                  NaN
#
# rental_id                                                         7165357  \
# addr_unit                                                       PENTHOUSE
# building_id                                                         20701
# bedrooms                                                                3
# bathrooms                                                               3
# size_sqft                                                            3000
# created_at                                            2018-05-10 13:47:30
# addr_street                                             149 SPRING STREET
# addr_city                                                        New York
# addr_zip                                                            10012
# addr_lat                                                          40.7245
# addr_lon                                                         -74.0013
# bin                                                           1.00772e+06
# bbl                                                            1005010035
# floor_count                                                             8
# year_built                                                           1900
# min_to_subway                                                         2.1
# has_doorman                                                             0
# has_elevator                                                            0
# has_fireplace                                                           1
# has_dishwasher                                                          0
# is_furnished                                                            0
# has_gym                                                                 0
# allows_pets                                                             0
# has_washer_dryer                                                        1
# has_garage                                                              0
# has_roofdeck                                                            1
# has_concierge                                                           0
# has_pool                                                                0
# has_garden                                                              0
# has_childrens_playroom                                                  0
# rent                                                                17500
# no_fee                                                                  0
# description             Ultra-rare Duplex Penthouse with Private Roofd...
# neighborhood                                                         Soho
# borough                                                         Manhattan
# unit                                                                   PH
# floornumber                                                             8
# line                                                                  NaN
#
# rental_id                                                         7196293  \
# addr_unit                                                             #1C
# building_id                                                        330241
# bedrooms                                                                1
# bathrooms                                                               1
# size_sqft                                                             500
# created_at                                            2018-05-21 15:52:37
# addr_street                                            431 CLASSON AVENUE
# addr_city                                                        Brooklyn
# addr_zip                                                            11238
# addr_lat                                                          40.6861
# addr_lon                                                         -73.9592
# bin                                                           3.05641e+06
# bbl                                                            3019700001
# floor_count                                                             4
# year_built                                                           1930
# min_to_subway                                                         3.1
# has_doorman                                                             0
# has_elevator                                                            0
# has_fireplace                                                           0
# has_dishwasher                                                          1
# is_furnished                                                            0
# has_gym                                                                 0
# allows_pets                                                             0
# has_washer_dryer                                                        0
# has_garage                                                              0
# has_roofdeck                                                            0
# has_concierge                                                           0
# has_pool                                                                0
# has_garden                                                              0
# has_childrens_playroom                                                  0
# rent                                                                 2100
# no_fee                                                                  0
# description             Clinton Hill Brooklyn comfortable 1br, living ...
# neighborhood                                           Bedford-Stuyvesant
# borough                                                          Brooklyn
# unit                                                                   1C
# floornumber                                                             1
# line                                                                    C
#
# rental_id                                                         7403512
# addr_unit                                                             #3R
# building_id                                                        380359
# bedrooms                                                                2
# bathrooms                                                               1
# size_sqft                                                               0
# created_at                                            2018-07-25 14:25:48
# addr_street                                               16 JUDGE STREET
# addr_city                                                        Brooklyn
# addr_zip                                                            11211
# addr_lat                                                          40.7134
# addr_lon                                                         -73.9401
# bin                                                           3.07041e+06
# bbl                                                            3029200005
# floor_count                                                             4
# year_built                                                           1920
# min_to_subway                                                      1.7167
# has_doorman                                                             0
# has_elevator                                                            0
# has_fireplace                                                           0
# has_dishwasher                                                          1
# is_furnished                                                            0
# has_gym                                                                 0
# allows_pets                                                             1
# has_washer_dryer                                                        0
# has_garage                                                              0
# has_roofdeck                                                            0
# has_concierge                                                           0
# has_pool                                                                0
# has_garden                                                              0
# has_childrens_playroom                                                  0
# rent                                                                 2800
# no_fee                                                                  1
# description             Heat and hot water included.\r\n\r\nMassive be...
# neighborhood                                                 Williamsburg
# borough                                                          Brooklyn
# unit                                                                   3R
# floornumber                                                             3
# line                                                                    R

# %% [markdown]
# #### Build training data

# %%
# extract usable features
feature_cols = [
    'bedrooms', 'year_built', 'bathrooms', 'min_to_subway', 
    'size_sqft', 'no_fee', 'has_doorman'
]
train_features = train_df[feature_cols] 

# impute missing values with medians
train_features = train_features.fillna(train_features.median(), axis=0)

# construct target vector
train_target = train_df['rent']

# %% [markdown]
# #### Fit model

# %%
lreg = LinearRegression()
lreg.fit(train_features, train_target)

rf = RandomForestRegressor()
rf.fit(train_features, train_target)
# Out:
# /Users/grant/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %% [markdown]
# #### Predict and Measure Using Test 1

# %%
test_features = test_df[feature_cols] 

# impute missing values with medians
test_features = test_features.fillna(train_features.median(), axis=0)

# construct predictions 
test_df['predicted'] = rf.predict(test_features)

mean_squared_error(test_df['rent'], test_df['predicted'])
# Out:
# 2728956.446064181

# %% [markdown]
# #### Combine Data, Predict Values for Test 2

# %%
master_df = train_df.append(test_df, sort=False)

master_features = master_df[feature_cols].fillna(master_df[feature_cols].median(), axis=0)
master_target = master_df['rent']

rf.fit(master_features, master_target)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %% [markdown]
# #### Create Submission File for `test2`

# %%
submit1_features = submit1_df[feature_cols].fillna(master_df[feature_cols].median(), axis=0)
submit1_df['predictions'] = rf.predict(submit1_features)
submit1_df['predictions'].to_csv('sample_submission1.csv', header=True)

submit1_df['fake_rent'] = np.ones(submit1_df['predictions'].shape) * master_target.median()
mean_squared_error(submit1_df['predictions'], submit1_df['fake_rent'])
# Out:
# 6987991.73172372

# %% [markdown]
# #### Create Submission File for `test3`

# %%
submit2_features = submit2_df[feature_cols].fillna(master_df[feature_cols].median(), axis=0)
submit2_df['predictions'] = rf.predict(submit2_features)
submit2_df['predictions'].to_csv('sample_submission2.csv', header=True)

submit2_df['fake_rent'] = np.ones(submit2_df['predictions'].shape) * master_target.median()
mean_squared_error(submit2_df['predictions'], submit2_df['fake_rent'])
# Out:
# 5986625.776536009

# %%
helpers.get_squared(4)
# Out:
# 16
